# %%
# !ls
# Out:
# CODE_OF_CONDUCT.md  README.md  habitat		  res	     train.log
# CONTRIBUTING.md     configs    habitat.egg-info   setup.cfg
# Dockerfile	    data       habitat_baselines  setup.py
# LICENSE		    docs       pyproject.toml	  tb
# MANIFEST.in	    examples   requirements.txt   test

# %%
# !ln -s /data /habitat-api/data
# Out:
# ln: failed to create symbolic link '/habitat-api/data/data': File exists

# %%
# %cd ../../habitat-api/
# !ls
# Out:
# /habitat-api
# CODE_OF_CONDUCT.md  README.md  habitat		  res	     train.log
# CONTRIBUTING.md     configs    habitat.egg-info   setup.cfg
# Dockerfile	    data       habitat_baselines  setup.py
# LICENSE		    docs       pyproject.toml	  tb
# MANIFEST.in	    examples   requirements.txt   test

# %%
# !sudo add-apt-repository ppa:ubuntu-toolchain-r/test -y
# !sudo apt-get update -y
# !sudo apt-get install gcc-4.9 -y
# !sudo apt-get upgrade libstdc++6 -y
# Out:
# gpg: keyring `/tmp/tmpujeuw_s0/secring.gpg' created
# gpg: keyring `/tmp/tmpujeuw_s0/pubring.gpg' created
# gpg: requesting key BA9EF27F from hkp server keyserver.ubuntu.com
# gpg: /tmp/tmpujeuw_s0/trustdb.gpg: trustdb created
# gpg: key BA9EF27F: public key "Launchpad Toolchain builds" imported
# gpg: Total number processed: 1
# gpg:               imported: 1  (RSA: 1)
# OK
# Hit:1 http://security.ubuntu.com/ubuntu xenial-security InRelease
# Hit:2 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu xenial InRelease
# Ign:3 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1604/x86_64  InRelease
# Hit:4 http://packages.ros.org/ros/ubuntu xenial InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu xenial InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu xenial-updates InRelease
# Ign:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu xenial-backports InRelease
# ...

# %%
# !bash habitat_baselines/rl/ddppo/single_node.sh
# Out:
# + python -u -m torch.distributed.launch --use_env --nproc_per_node 3 habitat_baselines/run.py --exp-config habitat_baselines/config/pointnav/ddppo_pointnav.yaml --run-type train
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# ...

# %%
# !bash habitat_baselines/rl/ddppo/multi_node_slurm.sh

# %%
# !bash habitat_baselines/rl/ddppo/single_node.sh
# Out:
# + python -u -m torch.distributed.launch --use_env --nproc_per_node 3 habitat_baselines/run.py --exp-config habitat_baselines/config/pointnav/ddppo_pointnav.yaml --run-type eval
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# /opt/conda/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# ...

# %%
sd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-e3a5a2604e99> in <module>
# ----> 1 sd
#
# NameError: name 'sd' is not defined
