# %%
# !ls
# Out:
# DDPO_single_node_eval.ipynb   Loss.py	      README.md       Vec_env.py
# DDPO_single_node_train.ipynb  Model.py	      Training.ipynb  media
# Data.py			      Model_dense.py  Utils.py

# %%
# !ln -s /data /habitat-api/data
# Out:
# ln: failed to create symbolic link '/habitat-api/data/data': File exists

# %%
# %cd ../../habitat-api/
# !ls
# Out:
# /habitat-api
# CODE_OF_CONDUCT.md  README.md  habitat		  res	     train.log
# CONTRIBUTING.md     configs    habitat.egg-info   setup.cfg
# Dockerfile	    data       habitat_baselines  setup.py
# LICENSE		    docs       pyproject.toml	  tb
# MANIFEST.in	    examples   requirements.txt   test

# %%
# !sudo add-apt-repository ppa:ubuntu-toolchain-r/test -y
# !sudo apt-get update -y
# !sudo apt-get install gcc-4.9 -y
# !sudo apt-get upgrade libstdc++6 -y
# Out:
# gpg: keyring `/tmp/tmpjabgnp47/secring.gpg' created
# gpg: keyring `/tmp/tmpjabgnp47/pubring.gpg' created
# gpg: requesting key BA9EF27F from hkp server keyserver.ubuntu.com
# gpg: /tmp/tmpjabgnp47/trustdb.gpg: trustdb created
# gpg: key BA9EF27F: public key "Launchpad Toolchain builds" imported
# gpg: Total number processed: 1
# gpg:               imported: 1  (RSA: 1)
# OK
# Hit:1 http://ppa.launchpad.net/ubuntu-toolchain-r/test/ubuntu xenial InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu xenial InRelease
# Hit:3 http://security.ubuntu.com/ubuntu xenial-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu xenial-updates InRelease
# Ign:5 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1604/x86_64  InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu xenial-backports InRelease
# Ign:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  InRelease
# Hit:8 http://packages.ros.org/ros/ubuntu xenial InRelease
# Ign:9 http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  InRelease
# Hit:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  Release
# Hit:11 http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1604/x86_64  Release
# Hit:12 http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  Release
# Reading package lists... Done
# W: Duplicate sources.list entry https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  Release
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# gcc-4.9 is already the newest version (4.9.4-2ubuntu1~16.04).
# 0 upgraded, 0 newly installed, 0 to remove and 28 not upgraded.
# W: Duplicate sources.list entry https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  Release
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libstdc++6 is already the newest version (9.2.1-17ubuntu1~16.04).
# Calculating upgrade... Done
# The following packages have been kept back:
#   cpp-5 g++-5 gcc-5 gcc-5-base gcc-6-base gcc-6-base:i386 gfortran-5 libasan2
#   libcilkrts5 libgcc-5-dev libgcc1 libgcc1:i386 libgfortran-5-dev libgfortran3
#   libmpx0 libnccl2 libnvinfer-dev libnvinfer-plugin-dev libnvinfer-plugin7
#   libnvinfer7 libnvonnxparsers-dev libnvonnxparsers7 libnvparsers-dev
#   libnvparsers7 libstdc++-5-dev libubsan0 python-libnvinfer python3-libnvinfer
# 0 upgraded, 0 newly installed, 0 to remove and 28 not upgraded.
# W: Duplicate sources.list entry https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  Release

# %% [markdown]
# # Изменяем файл single_node.sh: train --> eval

# %%
# !bash habitat_baselines/rl/ddppo/single_node.sh
# Out:
# + python -u -m torch.distributed.launch --use_env --nproc_per_node 1 habitat_baselines/run.py --exp-config habitat_baselines/config/pointnav/ddppo_pointnav.yaml --run-type eval
# 2020-02-26 07:42:35,139 config: BASE_TASK_CONFIG_PATH: configs/tasks/pointnav_gibson.yaml
# CHECKPOINT_FOLDER: data/new_checkpoints
# CHECKPOINT_INTERVAL: 50
# CMD_TRAILING_OPTS: []
# ENV_NAME: NavRLEnv
# EVAL:
#   SPLIT: val
#   USE_CKPT_CONFIG: True
# EVAL_CKPT_PATH_DIR: data/new_checkpoints
# LOG_FILE: train.log
# LOG_INTERVAL: 10
# NUM_PROCESSES: 4
# NUM_UPDATES: 10000
# ORBSLAM2:
#   ANGLE_TH: 0.2617993877991494
#   BETA: 100
#   CAMERA_HEIGHT: 1.25
#   DEPTH_DENORM: 10.0
#   DIST_REACHED_TH: 0.15
#   DIST_TO_STOP: 0.05
#   D_OBSTACLE_MAX: 4.0
#   D_OBSTACLE_MIN: 0.1
#   H_OBSTACLE_MAX: 1.25
#   H_OBSTACLE_MIN: 0.375
#   MAP_CELL_SIZE: 0.1
#   MAP_SIZE: 40
#   MIN_PTS_IN_OBSTACLE: 320.0
#   NEXT_WAYPOINT_TH: 0.5
#   NUM_ACTIONS: 3
#   PLANNER_MAX_STEPS: 500
#   PREPROCESS_MAP: True
#   SLAM_SETTINGS_PATH: habitat_baselines/slambased/data/mp3d3_small1k.yaml
#   SLAM_VOCAB_PATH: habitat_baselines/slambased/data/ORBvoc.txt
# RL:
#   DDPPO:
#     backbone: resnet50
#     distrib_backend: GLOO
#     num_recurrent_layers: 2
#     pretrained: False
#     pretrained_encoder: False
#     pretrained_weights: data/ddppo-models/gibson-2plus-resnet50.pth
#     reset_critic: True
#     rnn_type: LSTM
#     sync_frac: 0.6
#     train_encoder: True
#   PPO:
#     clip_param: 0.2
#     entropy_coef: 0.01
#     eps: 1e-05
#     gamma: 0.99
#     hidden_size: 512
#     lr: 0.00025
#     max_grad_norm: 0.2
#     num_mini_batch: 2
#     num_steps: 128
#     ppo_epoch: 2
#     reward_window_size: 50
#     tau: 0.95
#     use_gae: True
#     use_linear_clip_decay: False
#     use_linear_lr_decay: False
#     use_normalized_advantage: False
#     value_loss_coef: 0.5
#   REWARD_MEASURE: distance_to_goal
#   SLACK_REWARD: -0.01
#   SUCCESS_MEASURE: spl
#   SUCCESS_REWARD: 2.5
# SENSORS: ['DEPTH_SENSOR']
# SIMULATOR_GPU_ID: 0
# TASK_CONFIG:
#   DATASET:
#     CONTENT_SCENES: ['*']
#     DATA_PATH: data/datasets/pointnav/gibson/v1/{split}/{split}.json.gz
#     SCENES_DIR: data/scene_datasets
#     SPLIT: train
#     TYPE: PointNav-v1
#   ENVIRONMENT:
#     ITERATOR_OPTIONS:
#       CYCLE: True
#       GROUP_BY_SCENE: True
#       MAX_SCENE_REPEAT_EPISODES: -1
#       MAX_SCENE_REPEAT_STEPS: 10000
#       NUM_EPISODE_SAMPLE: -1
#       SHUFFLE: True
#       STEP_REPETITION_RANGE: 0.2
#     MAX_EPISODE_SECONDS: 10000000
#     MAX_EPISODE_STEPS: 500
#   PYROBOT:
#     BASE_CONTROLLER: proportional
#     BASE_PLANNER: none
#     BUMP_SENSOR:
#       TYPE: PyRobotBumpSensor
#     DEPTH_SENSOR:
#       CENTER_CROP: False
#       HEIGHT: 480
#       MAX_DEPTH: 5.0
#       MIN_DEPTH: 0.0
#       NORMALIZE_DEPTH: True
#       TYPE: PyRobotDepthSensor
#       WIDTH: 640
#     LOCOBOT:
#       ACTIONS: ['BASE_ACTIONS', 'CAMERA_ACTIONS']
#       BASE_ACTIONS: ['go_to_relative', 'go_to_absolute']
#       CAMERA_ACTIONS: ['set_pan', 'set_tilt', 'set_pan_tilt']
#     RGB_SENSOR:
#       CENTER_CROP: False
#       HEIGHT: 480
#       TYPE: PyRobotRGBSensor
#       WIDTH: 640
#     ROBOT: locobot
#     ROBOTS: ['locobot']
#     SENSORS: ['RGB_SENSOR', 'DEPTH_SENSOR', 'BUMP_SENSOR']
#   SEED: 100
#   SIMULATOR:
#     ACTION_SPACE_CONFIG: v0
#     AGENTS: ['AGENT_0']
#     AGENT_0:
#       ANGULAR_ACCELERATION: 12.56
#       ANGULAR_FRICTION: 1.0
#       COEFFICIENT_OF_RESTITUTION: 0.0
#       HEIGHT: 1.5
#       IS_SET_START_STATE: False
#       LINEAR_ACCELERATION: 20.0
#       LINEAR_FRICTION: 0.5
#       MASS: 32.0
#       RADIUS: 0.1
#       SENSORS: ['RGB_SENSOR']
#       START_POSITION: [0, 0, 0]
#       START_ROTATION: [0, 0, 0, 1]
#     DEFAULT_AGENT_ID: 0
#     DEPTH_SENSOR:
#       HEIGHT: 256
#       HFOV: 90
#       MAX_DEPTH: 10.0
#       MIN_DEPTH: 0.0
#       NORMALIZE_DEPTH: True
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimDepthSensor
#       WIDTH: 256
#     FORWARD_STEP_SIZE: 0.25
#     HABITAT_SIM_V0:
#       ALLOW_SLIDING: True
#       ENABLE_PHYSICS: False
#       GPU_DEVICE_ID: 0
#       GPU_GPU: False
#       PHYSICS_CONFIG_FILE: ./data/default.phys_scene_config.json
#     RGB_SENSOR:
#       HEIGHT: 256
#       HFOV: 90
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimRGBSensor
#       WIDTH: 256
#     SCENE: data/scene_datasets/habitat-test-scenes/van-gogh-room.glb
#     SEED: 100
#     SEMANTIC_SENSOR:
#       HEIGHT: 480
#       HFOV: 90
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimSemanticSensor
#       WIDTH: 640
#     TILT_ANGLE: 15
#     TURN_ANGLE: 10
#     TYPE: Sim-v0
#   TASK:
#     ACTIONS:
#       ANSWER:
#         TYPE: AnswerAction
#       LOOK_DOWN:
#         TYPE: LookDownAction
#       LOOK_UP:
#         TYPE: LookUpAction
#       MOVE_FORWARD:
#         TYPE: MoveForwardAction
#       STOP:
#         TYPE: StopAction
#       TELEPORT:
#         TYPE: TeleportAction
#       TURN_LEFT:
#         TYPE: TurnLeftAction
#       TURN_RIGHT:
#         TYPE: TurnRightAction
#     ANSWER_ACCURACY:
#       TYPE: AnswerAccuracy
#     COLLISIONS:
#       TYPE: Collisions
#     COMPASS_SENSOR:
#       TYPE: CompassSensor
#     CORRECT_ANSWER:
#       TYPE: CorrectAnswer
#     DISTANCE_TO_GOAL:
#       DISTANCE_TO: POINT
#       TYPE: DistanceToGoal
#     EPISODE_INFO:
#       TYPE: EpisodeInfo
#     GOAL_SENSOR_UUID: pointgoal_with_gps_compass
#     GPS_SENSOR:
#       DIMENSIONALITY: 2
#       TYPE: GPSSensor
#     HEADING_SENSOR:
#       TYPE: HeadingSensor
#     INSTRUCTION_SENSOR:
#       TYPE: InstructionSensor
#     INSTRUCTION_SENSOR_UUID: instruction
#     MEASUREMENTS: ['DISTANCE_TO_GOAL', 'SPL']
#     OBJECTGOAL_SENSOR:
#       GOAL_SPEC: TASK_CATEGORY_ID
#       GOAL_SPEC_MAX_VAL: 50
#       TYPE: ObjectGoalSensor
#     POINTGOAL_SENSOR:
#       DIMENSIONALITY: 2
#       GOAL_FORMAT: POLAR
#       TYPE: PointGoalSensor
#     POINTGOAL_WITH_GPS_COMPASS_SENSOR:
#       DIMENSIONALITY: 2
#       GOAL_FORMAT: POLAR
#       TYPE: PointGoalWithGPSCompassSensor
#     POSSIBLE_ACTIONS: ['STOP', 'MOVE_FORWARD', 'TURN_LEFT', 'TURN_RIGHT']
#     PROXIMITY_SENSOR:
#       MAX_DETECTION_RADIUS: 2.0
#       TYPE: ProximitySensor
#     QUESTION_SENSOR:
#       TYPE: QuestionSensor
#     SENSORS: ['POINTGOAL_WITH_GPS_COMPASS_SENSOR']
#     SPL:
#       SUCCESS_DISTANCE: 0.2
#       TYPE: SPL
#     SUCCESS_DISTANCE: 0.2
#     TOP_DOWN_MAP:
#       DRAW_BORDER: True
#       DRAW_GOAL_AABBS: True
#       DRAW_GOAL_POSITIONS: True
#       DRAW_SHORTEST_PATH: True
#       DRAW_SOURCE: True
#       DRAW_VIEW_POINTS: True
#       FOG_OF_WAR:
#         DRAW: True
#         FOV: 90
#         VISIBILITY_DIST: 5.0
#       MAP_PADDING: 3
#       MAP_RESOLUTION: 1250
#       MAX_EPISODE_STEPS: 1000
#       NUM_TOPDOWN_MAP_SAMPLE_POINTS: 20000
#       TYPE: TopDownMap
#     TYPE: Nav-v0
# TENSORBOARD_DIR: tb
# TEST_EPISODE_COUNT: 994
# TORCH_GPU_ID: 0
# TRAINER_NAME: ddppo
# VIDEO_DIR: video_dir
# VIDEO_OPTION: []
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2020-02-26 07:42:39,622 =======current_ckpt: data/new_checkpoints/ckpt.0.pth=======
# 2020-02-26 07:42:39,695 env config: BASE_TASK_CONFIG_PATH: configs/tasks/pointnav_gibson.yaml
# CHECKPOINT_FOLDER: data/new_checkpoints
# CHECKPOINT_INTERVAL: 50
# CMD_TRAILING_OPTS: []
# ENV_NAME: NavRLEnv
# EVAL:
#   SPLIT: val
#   USE_CKPT_CONFIG: True
# EVAL_CKPT_PATH_DIR: data/new_checkpoints
# LOG_FILE: train.log
# LOG_INTERVAL: 10
# NUM_PROCESSES: 4
# NUM_UPDATES: 10000
# ORBSLAM2:
#   ANGLE_TH: 0.2617993877991494
#   BETA: 100
#   CAMERA_HEIGHT: 1.25
#   DEPTH_DENORM: 10.0
#   DIST_REACHED_TH: 0.15
#   DIST_TO_STOP: 0.05
#   D_OBSTACLE_MAX: 4.0
#   D_OBSTACLE_MIN: 0.1
#   H_OBSTACLE_MAX: 1.25
#   H_OBSTACLE_MIN: 0.375
#   MAP_CELL_SIZE: 0.1
#   MAP_SIZE: 40
#   MIN_PTS_IN_OBSTACLE: 320.0
#   NEXT_WAYPOINT_TH: 0.5
#   NUM_ACTIONS: 3
#   PLANNER_MAX_STEPS: 500
#   PREPROCESS_MAP: True
#   SLAM_SETTINGS_PATH: habitat_baselines/slambased/data/mp3d3_small1k.yaml
#   SLAM_VOCAB_PATH: habitat_baselines/slambased/data/ORBvoc.txt
# RL:
#   DDPPO:
#     backbone: resnet50
#     distrib_backend: GLOO
#     num_recurrent_layers: 2
#     pretrained: False
#     pretrained_encoder: False
#     pretrained_weights: data/ddppo-models/gibson-2plus-resnet50.pth
#     reset_critic: True
#     rnn_type: LSTM
#     sync_frac: 0.6
#     train_encoder: True
#   PPO:
#     clip_param: 0.2
#     entropy_coef: 0.01
#     eps: 1e-05
#     gamma: 0.99
#     hidden_size: 512
#     lr: 0.00025
#     max_grad_norm: 0.2
#     num_mini_batch: 2
#     num_steps: 128
#     ppo_epoch: 2
#     reward_window_size: 50
#     tau: 0.95
#     use_gae: True
#     use_linear_clip_decay: False
#     use_linear_lr_decay: False
#     use_normalized_advantage: False
#     value_loss_coef: 0.5
#   REWARD_MEASURE: distance_to_goal
#   SLACK_REWARD: -0.01
#   SUCCESS_MEASURE: spl
#   SUCCESS_REWARD: 2.5
# SENSORS: ['DEPTH_SENSOR']
# SIMULATOR_GPU_ID: 0
# TASK_CONFIG:
#   DATASET:
#     CONTENT_SCENES: ['*']
#     DATA_PATH: data/datasets/pointnav/gibson/v1/{split}/{split}.json.gz
#     SCENES_DIR: data/scene_datasets
#     SPLIT: val
#     TYPE: PointNav-v1
#   ENVIRONMENT:
#     ITERATOR_OPTIONS:
#       CYCLE: True
#       GROUP_BY_SCENE: True
#       MAX_SCENE_REPEAT_EPISODES: -1
#       MAX_SCENE_REPEAT_STEPS: 10000
#       NUM_EPISODE_SAMPLE: -1
#       SHUFFLE: True
#       STEP_REPETITION_RANGE: 0.2
#     MAX_EPISODE_SECONDS: 10000000
#     MAX_EPISODE_STEPS: 500
#   PYROBOT:
#     BASE_CONTROLLER: proportional
#     BASE_PLANNER: none
#     BUMP_SENSOR:
#       TYPE: PyRobotBumpSensor
#     DEPTH_SENSOR:
#       CENTER_CROP: False
#       HEIGHT: 480
#       MAX_DEPTH: 5.0
#       MIN_DEPTH: 0.0
#       NORMALIZE_DEPTH: True
#       TYPE: PyRobotDepthSensor
#       WIDTH: 640
#     LOCOBOT:
#       ACTIONS: ['BASE_ACTIONS', 'CAMERA_ACTIONS']
#       BASE_ACTIONS: ['go_to_relative', 'go_to_absolute']
#       CAMERA_ACTIONS: ['set_pan', 'set_tilt', 'set_pan_tilt']
#     RGB_SENSOR:
#       CENTER_CROP: False
#       HEIGHT: 480
#       TYPE: PyRobotRGBSensor
#       WIDTH: 640
#     ROBOT: locobot
#     ROBOTS: ['locobot']
#     SENSORS: ['RGB_SENSOR', 'DEPTH_SENSOR', 'BUMP_SENSOR']
#   SEED: 100
#   SIMULATOR:
#     ACTION_SPACE_CONFIG: v0
#     AGENTS: ['AGENT_0']
#     AGENT_0:
#       ANGULAR_ACCELERATION: 12.56
#       ANGULAR_FRICTION: 1.0
#       COEFFICIENT_OF_RESTITUTION: 0.0
#       HEIGHT: 1.5
#       IS_SET_START_STATE: False
#       LINEAR_ACCELERATION: 20.0
#       LINEAR_FRICTION: 0.5
#       MASS: 32.0
#       RADIUS: 0.1
#       SENSORS: ['DEPTH_SENSOR']
#       START_POSITION: [0, 0, 0]
#       START_ROTATION: [0, 0, 0, 1]
#     DEFAULT_AGENT_ID: 0
#     DEPTH_SENSOR:
#       HEIGHT: 256
#       HFOV: 90
#       MAX_DEPTH: 10.0
#       MIN_DEPTH: 0.0
#       NORMALIZE_DEPTH: True
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimDepthSensor
#       WIDTH: 256
#     FORWARD_STEP_SIZE: 0.25
#     HABITAT_SIM_V0:
#       ALLOW_SLIDING: True
#       ENABLE_PHYSICS: False
#       GPU_DEVICE_ID: 0
#       GPU_GPU: False
#       PHYSICS_CONFIG_FILE: ./data/default.phys_scene_config.json
#     RGB_SENSOR:
#       HEIGHT: 256
#       HFOV: 90
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimRGBSensor
#       WIDTH: 256
#     SCENE: data/scene_datasets/habitat-test-scenes/van-gogh-room.glb
#     SEED: 100
#     SEMANTIC_SENSOR:
#       HEIGHT: 480
#       HFOV: 90
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimSemanticSensor
#       WIDTH: 640
#     TILT_ANGLE: 15
#     TURN_ANGLE: 10
#     TYPE: Sim-v0
#   TASK:
#     ACTIONS:
#       ANSWER:
#         TYPE: AnswerAction
#       LOOK_DOWN:
#         TYPE: LookDownAction
#       LOOK_UP:
#         TYPE: LookUpAction
#       MOVE_FORWARD:
#         TYPE: MoveForwardAction
#       STOP:
#         TYPE: StopAction
#       TELEPORT:
#         TYPE: TeleportAction
#       TURN_LEFT:
#         TYPE: TurnLeftAction
#       TURN_RIGHT:
#         TYPE: TurnRightAction
#     ANSWER_ACCURACY:
#       TYPE: AnswerAccuracy
#     COLLISIONS:
#       TYPE: Collisions
#     COMPASS_SENSOR:
#       TYPE: CompassSensor
#     CORRECT_ANSWER:
#       TYPE: CorrectAnswer
#     DISTANCE_TO_GOAL:
#       DISTANCE_TO: POINT
#       TYPE: DistanceToGoal
#     EPISODE_INFO:
#       TYPE: EpisodeInfo
#     GOAL_SENSOR_UUID: pointgoal_with_gps_compass
#     GPS_SENSOR:
#       DIMENSIONALITY: 2
#       TYPE: GPSSensor
#     HEADING_SENSOR:
#       TYPE: HeadingSensor
#     INSTRUCTION_SENSOR:
#       TYPE: InstructionSensor
#     INSTRUCTION_SENSOR_UUID: instruction
#     MEASUREMENTS: ['DISTANCE_TO_GOAL', 'SPL']
#     OBJECTGOAL_SENSOR:
#       GOAL_SPEC: TASK_CATEGORY_ID
#       GOAL_SPEC_MAX_VAL: 50
#       TYPE: ObjectGoalSensor
#     POINTGOAL_SENSOR:
#       DIMENSIONALITY: 2
#       GOAL_FORMAT: POLAR
#       TYPE: PointGoalSensor
#     POINTGOAL_WITH_GPS_COMPASS_SENSOR:
#       DIMENSIONALITY: 2
#       GOAL_FORMAT: POLAR
#       TYPE: PointGoalWithGPSCompassSensor
#     POSSIBLE_ACTIONS: ['STOP', 'MOVE_FORWARD', 'TURN_LEFT', 'TURN_RIGHT']
#     PROXIMITY_SENSOR:
#       MAX_DETECTION_RADIUS: 2.0
#       TYPE: ProximitySensor
#     QUESTION_SENSOR:
#       TYPE: QuestionSensor
#     SENSORS: ['POINTGOAL_WITH_GPS_COMPASS_SENSOR']
#     SPL:
#       SUCCESS_DISTANCE: 0.2
#       TYPE: SPL
#     SUCCESS_DISTANCE: 0.2
#     TOP_DOWN_MAP:
#       DRAW_BORDER: True
#       DRAW_GOAL_AABBS: True
#       DRAW_GOAL_POSITIONS: True
#       DRAW_SHORTEST_PATH: True
#       DRAW_SOURCE: True
#       DRAW_VIEW_POINTS: True
#       FOG_OF_WAR:
#         DRAW: True
#         FOV: 90
#         VISIBILITY_DIST: 5.0
#       MAP_PADDING: 3
#       MAP_RESOLUTION: 1250
#       MAX_EPISODE_STEPS: 1000
#       NUM_TOPDOWN_MAP_SAMPLE_POINTS: 20000
#       TYPE: TopDownMap
#     TYPE: Nav-v0
# TENSORBOARD_DIR: tb
# TEST_EPISODE_COUNT: 994
# TORCH_GPU_ID: 0
# TRAINER_NAME: ddppo
# VIDEO_DIR: video_dir
# VIDEO_OPTION: []
# 2020-02-26 07:42:39,695 Initializing dataset PointNav-v1
# 2020-02-26 07:42:41,163 Initializing dataset PointNav-v1
# 2020-02-26 07:42:41,163 Initializing dataset PointNav-v1
# 2020-02-26 07:42:41,163 Initializing dataset PointNav-v1
# 2020-02-26 07:42:41,176 initializing sim Sim-v0
# 2020-02-26 07:42:41,176 initializing sim Sim-v0
# 2020-02-26 07:42:41,176 initializing sim Sim-v0
# 2020-02-26 07:42:41,188 Initializing dataset PointNav-v1
# 2020-02-26 07:42:41,201 initializing sim Sim-v0
# 2020-02-26 07:42:46,157 Initializing task Nav-v0
# 2020-02-26 07:42:46,422 Initializing task Nav-v0
# 2020-02-26 07:42:46,424 Initializing task Nav-v0
# 2020-02-26 07:42:46,438 Initializing task Nav-v0
# 2020-02-26 07:43:13,180 Average episode reward: -0.038940
# 2020-02-26 07:43:13,181 Average episode success: 1.000000
# 2020-02-26 07:43:13,181 Average episode distance_to_goal: 6.285122
# 2020-02-26 07:43:15,525 =======current_ckpt: data/new_checkpoints/ckpt.1.pth=======
# 2020-02-26 07:43:15,598 env config: BASE_TASK_CONFIG_PATH: configs/tasks/pointnav_gibson.yaml
# CHECKPOINT_FOLDER: data/new_checkpoints
# CHECKPOINT_INTERVAL: 50
# CMD_TRAILING_OPTS: []
# ENV_NAME: NavRLEnv
# EVAL:
#   SPLIT: val
#   USE_CKPT_CONFIG: True
# EVAL_CKPT_PATH_DIR: data/new_checkpoints
# LOG_FILE: train.log
# LOG_INTERVAL: 10
# NUM_PROCESSES: 4
# NUM_UPDATES: 10000
# ORBSLAM2:
#   ANGLE_TH: 0.2617993877991494
#   BETA: 100
#   CAMERA_HEIGHT: 1.25
#   DEPTH_DENORM: 10.0
#   DIST_REACHED_TH: 0.15
#   DIST_TO_STOP: 0.05
#   D_OBSTACLE_MAX: 4.0
#   D_OBSTACLE_MIN: 0.1
#   H_OBSTACLE_MAX: 1.25
#   H_OBSTACLE_MIN: 0.375
#   MAP_CELL_SIZE: 0.1
#   MAP_SIZE: 40
#   MIN_PTS_IN_OBSTACLE: 320.0
#   NEXT_WAYPOINT_TH: 0.5
#   NUM_ACTIONS: 3
#   PLANNER_MAX_STEPS: 500
#   PREPROCESS_MAP: True
#   SLAM_SETTINGS_PATH: habitat_baselines/slambased/data/mp3d3_small1k.yaml
#   SLAM_VOCAB_PATH: habitat_baselines/slambased/data/ORBvoc.txt
# RL:
#   DDPPO:
#     backbone: resnet50
#     distrib_backend: GLOO
#     num_recurrent_layers: 2
#     pretrained: False
#     pretrained_encoder: False
#     pretrained_weights: data/ddppo-models/gibson-2plus-resnet50.pth
#     reset_critic: True
#     rnn_type: LSTM
#     sync_frac: 0.6
#     train_encoder: True
#   PPO:
#     clip_param: 0.2
#     entropy_coef: 0.01
#     eps: 1e-05
#     gamma: 0.99
#     hidden_size: 512
#     lr: 0.00025
#     max_grad_norm: 0.2
#     num_mini_batch: 2
#     num_steps: 128
#     ppo_epoch: 2
#     reward_window_size: 50
#     tau: 0.95
#     use_gae: True
#     use_linear_clip_decay: False
#     use_linear_lr_decay: False
#     use_normalized_advantage: False
#     value_loss_coef: 0.5
#   REWARD_MEASURE: distance_to_goal
#   SLACK_REWARD: -0.01
#   SUCCESS_MEASURE: spl
#   SUCCESS_REWARD: 2.5
# SENSORS: ['DEPTH_SENSOR']
# SIMULATOR_GPU_ID: 0
# TASK_CONFIG:
#   DATASET:
#     CONTENT_SCENES: ['*']
#     DATA_PATH: data/datasets/pointnav/gibson/v1/{split}/{split}.json.gz
#     SCENES_DIR: data/scene_datasets
#     SPLIT: val
#     TYPE: PointNav-v1
#   ENVIRONMENT:
#     ITERATOR_OPTIONS:
#       CYCLE: True
#       GROUP_BY_SCENE: True
#       MAX_SCENE_REPEAT_EPISODES: -1
#       MAX_SCENE_REPEAT_STEPS: 10000
#       NUM_EPISODE_SAMPLE: -1
#       SHUFFLE: True
#       STEP_REPETITION_RANGE: 0.2
#     MAX_EPISODE_SECONDS: 10000000
#     MAX_EPISODE_STEPS: 500
#   PYROBOT:
#     BASE_CONTROLLER: proportional
#     BASE_PLANNER: none
#     BUMP_SENSOR:
#       TYPE: PyRobotBumpSensor
#     DEPTH_SENSOR:
#       CENTER_CROP: False
#       HEIGHT: 480
#       MAX_DEPTH: 5.0
#       MIN_DEPTH: 0.0
#       NORMALIZE_DEPTH: True
#       TYPE: PyRobotDepthSensor
#       WIDTH: 640
#     LOCOBOT:
#       ACTIONS: ['BASE_ACTIONS', 'CAMERA_ACTIONS']
#       BASE_ACTIONS: ['go_to_relative', 'go_to_absolute']
#       CAMERA_ACTIONS: ['set_pan', 'set_tilt', 'set_pan_tilt']
#     RGB_SENSOR:
#       CENTER_CROP: False
#       HEIGHT: 480
#       TYPE: PyRobotRGBSensor
#       WIDTH: 640
#     ROBOT: locobot
#     ROBOTS: ['locobot']
#     SENSORS: ['RGB_SENSOR', 'DEPTH_SENSOR', 'BUMP_SENSOR']
#   SEED: 100
#   SIMULATOR:
#     ACTION_SPACE_CONFIG: v0
#     AGENTS: ['AGENT_0']
#     AGENT_0:
#       ANGULAR_ACCELERATION: 12.56
#       ANGULAR_FRICTION: 1.0
#       COEFFICIENT_OF_RESTITUTION: 0.0
#       HEIGHT: 1.5
#       IS_SET_START_STATE: False
#       LINEAR_ACCELERATION: 20.0
#       LINEAR_FRICTION: 0.5
#       MASS: 32.0
#       RADIUS: 0.1
#       SENSORS: ['DEPTH_SENSOR']
#       START_POSITION: [0, 0, 0]
#       START_ROTATION: [0, 0, 0, 1]
#     DEFAULT_AGENT_ID: 0
#     DEPTH_SENSOR:
#       HEIGHT: 256
#       HFOV: 90
#       MAX_DEPTH: 10.0
#       MIN_DEPTH: 0.0
#       NORMALIZE_DEPTH: True
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimDepthSensor
#       WIDTH: 256
#     FORWARD_STEP_SIZE: 0.25
#     HABITAT_SIM_V0:
#       ALLOW_SLIDING: True
#       ENABLE_PHYSICS: False
#       GPU_DEVICE_ID: 0
#       GPU_GPU: False
#       PHYSICS_CONFIG_FILE: ./data/default.phys_scene_config.json
#     RGB_SENSOR:
#       HEIGHT: 256
#       HFOV: 90
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimRGBSensor
#       WIDTH: 256
#     SCENE: data/scene_datasets/habitat-test-scenes/van-gogh-room.glb
#     SEED: 100
#     SEMANTIC_SENSOR:
#       HEIGHT: 480
#       HFOV: 90
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimSemanticSensor
#       WIDTH: 640
#     TILT_ANGLE: 15
#     TURN_ANGLE: 10
#     TYPE: Sim-v0
#   TASK:
#     ACTIONS:
#       ANSWER:
#         TYPE: AnswerAction
#       LOOK_DOWN:
#         TYPE: LookDownAction
#       LOOK_UP:
#         TYPE: LookUpAction
#       MOVE_FORWARD:
#         TYPE: MoveForwardAction
#       STOP:
#         TYPE: StopAction
#       TELEPORT:
#         TYPE: TeleportAction
#       TURN_LEFT:
#         TYPE: TurnLeftAction
#       TURN_RIGHT:
#         TYPE: TurnRightAction
#     ANSWER_ACCURACY:
#       TYPE: AnswerAccuracy
#     COLLISIONS:
#       TYPE: Collisions
#     COMPASS_SENSOR:
#       TYPE: CompassSensor
#     CORRECT_ANSWER:
#       TYPE: CorrectAnswer
#     DISTANCE_TO_GOAL:
#       DISTANCE_TO: POINT
#       TYPE: DistanceToGoal
#     EPISODE_INFO:
#       TYPE: EpisodeInfo
#     GOAL_SENSOR_UUID: pointgoal_with_gps_compass
#     GPS_SENSOR:
#       DIMENSIONALITY: 2
#       TYPE: GPSSensor
#     HEADING_SENSOR:
#       TYPE: HeadingSensor
#     INSTRUCTION_SENSOR:
#       TYPE: InstructionSensor
#     INSTRUCTION_SENSOR_UUID: instruction
#     MEASUREMENTS: ['DISTANCE_TO_GOAL', 'SPL']
#     OBJECTGOAL_SENSOR:
#       GOAL_SPEC: TASK_CATEGORY_ID
#       GOAL_SPEC_MAX_VAL: 50
#       TYPE: ObjectGoalSensor
#     POINTGOAL_SENSOR:
#       DIMENSIONALITY: 2
#       GOAL_FORMAT: POLAR
#       TYPE: PointGoalSensor
#     POINTGOAL_WITH_GPS_COMPASS_SENSOR:
#       DIMENSIONALITY: 2
#       GOAL_FORMAT: POLAR
#       TYPE: PointGoalWithGPSCompassSensor
#     POSSIBLE_ACTIONS: ['STOP', 'MOVE_FORWARD', 'TURN_LEFT', 'TURN_RIGHT']
#     PROXIMITY_SENSOR:
#       MAX_DETECTION_RADIUS: 2.0
#       TYPE: ProximitySensor
#     QUESTION_SENSOR:
#       TYPE: QuestionSensor
#     SENSORS: ['POINTGOAL_WITH_GPS_COMPASS_SENSOR']
#     SPL:
#       SUCCESS_DISTANCE: 0.2
#       TYPE: SPL
#     SUCCESS_DISTANCE: 0.2
#     TOP_DOWN_MAP:
#       DRAW_BORDER: True
#       DRAW_GOAL_AABBS: True
#       DRAW_GOAL_POSITIONS: True
#       DRAW_SHORTEST_PATH: True
#       DRAW_SOURCE: True
#       DRAW_VIEW_POINTS: True
#       FOG_OF_WAR:
#         DRAW: True
#         FOV: 90
#         VISIBILITY_DIST: 5.0
#       MAP_PADDING: 3
#       MAP_RESOLUTION: 1250
#       MAX_EPISODE_STEPS: 1000
#       NUM_TOPDOWN_MAP_SAMPLE_POINTS: 20000
#       TYPE: TopDownMap
#     TYPE: Nav-v0
# TENSORBOARD_DIR: tb
# TEST_EPISODE_COUNT: 994
# TORCH_GPU_ID: 0
# TRAINER_NAME: ddppo
# VIDEO_DIR: video_dir
# VIDEO_OPTION: []
# 2020-02-26 07:43:15,598 Initializing dataset PointNav-v1
# 2020-02-26 07:43:16,778 Initializing dataset PointNav-v1
# 2020-02-26 07:43:16,779 Initializing dataset PointNav-v1
# 2020-02-26 07:43:16,790 initializing sim Sim-v0
# 2020-02-26 07:43:16,791 initializing sim Sim-v0
# 2020-02-26 07:43:16,795 Initializing dataset PointNav-v1
# 2020-02-26 07:43:16,806 Initializing dataset PointNav-v1
# 2020-02-26 07:43:16,808 initializing sim Sim-v0
# 2020-02-26 07:43:16,819 initializing sim Sim-v0
# 2020-02-26 07:43:18,291 Initializing task Nav-v0
# 2020-02-26 07:43:18,363 Initializing task Nav-v0
# 2020-02-26 07:43:20,887 Initializing task Nav-v0
# 2020-02-26 07:43:21,119 Initializing task Nav-v0
# 2020-02-26 07:44:05,374 Average episode reward: 0.168161
# 2020-02-26 07:44:05,375 Average episode success: 1.000000
# 2020-02-26 07:44:05,375 Average episode distance_to_goal: 5.513075
# 2020-02-26 07:44:07,646 =======current_ckpt: data/new_checkpoints/ckpt.2.pth=======
# 2020-02-26 07:44:07,719 env config: BASE_TASK_CONFIG_PATH: configs/tasks/pointnav_gibson.yaml
# CHECKPOINT_FOLDER: data/new_checkpoints
# CHECKPOINT_INTERVAL: 50
# CMD_TRAILING_OPTS: []
# ENV_NAME: NavRLEnv
# EVAL:
#   SPLIT: val
#   USE_CKPT_CONFIG: True
# EVAL_CKPT_PATH_DIR: data/new_checkpoints
# LOG_FILE: train.log
# LOG_INTERVAL: 10
# NUM_PROCESSES: 4
# NUM_UPDATES: 10000
# ORBSLAM2:
#   ANGLE_TH: 0.2617993877991494
#   BETA: 100
#   CAMERA_HEIGHT: 1.25
#   DEPTH_DENORM: 10.0
#   DIST_REACHED_TH: 0.15
#   DIST_TO_STOP: 0.05
#   D_OBSTACLE_MAX: 4.0
#   D_OBSTACLE_MIN: 0.1
#   H_OBSTACLE_MAX: 1.25
#   H_OBSTACLE_MIN: 0.375
#   MAP_CELL_SIZE: 0.1
#   MAP_SIZE: 40
#   MIN_PTS_IN_OBSTACLE: 320.0
#   NEXT_WAYPOINT_TH: 0.5
#   NUM_ACTIONS: 3
#   PLANNER_MAX_STEPS: 500
#   PREPROCESS_MAP: True
#   SLAM_SETTINGS_PATH: habitat_baselines/slambased/data/mp3d3_small1k.yaml
#   SLAM_VOCAB_PATH: habitat_baselines/slambased/data/ORBvoc.txt
# RL:
#   DDPPO:
#     backbone: resnet50
#     distrib_backend: GLOO
#     num_recurrent_layers: 2
#     pretrained: False
#     pretrained_encoder: False
#     pretrained_weights: data/ddppo-models/gibson-2plus-resnet50.pth
#     reset_critic: True
#     rnn_type: LSTM
#     sync_frac: 0.6
#     train_encoder: True
#   PPO:
#     clip_param: 0.2
#     entropy_coef: 0.01
#     eps: 1e-05
#     gamma: 0.99
#     hidden_size: 512
#     lr: 0.00025
#     max_grad_norm: 0.2
#     num_mini_batch: 2
#     num_steps: 128
#     ppo_epoch: 2
#     reward_window_size: 50
#     tau: 0.95
#     use_gae: True
#     use_linear_clip_decay: False
#     use_linear_lr_decay: False
#     use_normalized_advantage: False
#     value_loss_coef: 0.5
#   REWARD_MEASURE: distance_to_goal
#   SLACK_REWARD: -0.01
#   SUCCESS_MEASURE: spl
#   SUCCESS_REWARD: 2.5
# SENSORS: ['DEPTH_SENSOR']
# SIMULATOR_GPU_ID: 0
# TASK_CONFIG:
#   DATASET:
#     CONTENT_SCENES: ['*']
#     DATA_PATH: data/datasets/pointnav/gibson/v1/{split}/{split}.json.gz
#     SCENES_DIR: data/scene_datasets
#     SPLIT: val
#     TYPE: PointNav-v1
#   ENVIRONMENT:
#     ITERATOR_OPTIONS:
#       CYCLE: True
#       GROUP_BY_SCENE: True
#       MAX_SCENE_REPEAT_EPISODES: -1
#       MAX_SCENE_REPEAT_STEPS: 10000
#       NUM_EPISODE_SAMPLE: -1
#       SHUFFLE: True
#       STEP_REPETITION_RANGE: 0.2
#     MAX_EPISODE_SECONDS: 10000000
#     MAX_EPISODE_STEPS: 500
#   PYROBOT:
#     BASE_CONTROLLER: proportional
#     BASE_PLANNER: none
#     BUMP_SENSOR:
#       TYPE: PyRobotBumpSensor
#     DEPTH_SENSOR:
#       CENTER_CROP: False
#       HEIGHT: 480
#       MAX_DEPTH: 5.0
#       MIN_DEPTH: 0.0
#       NORMALIZE_DEPTH: True
#       TYPE: PyRobotDepthSensor
#       WIDTH: 640
#     LOCOBOT:
#       ACTIONS: ['BASE_ACTIONS', 'CAMERA_ACTIONS']
#       BASE_ACTIONS: ['go_to_relative', 'go_to_absolute']
#       CAMERA_ACTIONS: ['set_pan', 'set_tilt', 'set_pan_tilt']
#     RGB_SENSOR:
#       CENTER_CROP: False
#       HEIGHT: 480
#       TYPE: PyRobotRGBSensor
#       WIDTH: 640
#     ROBOT: locobot
#     ROBOTS: ['locobot']
#     SENSORS: ['RGB_SENSOR', 'DEPTH_SENSOR', 'BUMP_SENSOR']
#   SEED: 100
#   SIMULATOR:
#     ACTION_SPACE_CONFIG: v0
#     AGENTS: ['AGENT_0']
#     AGENT_0:
#       ANGULAR_ACCELERATION: 12.56
#       ANGULAR_FRICTION: 1.0
#       COEFFICIENT_OF_RESTITUTION: 0.0
#       HEIGHT: 1.5
#       IS_SET_START_STATE: False
#       LINEAR_ACCELERATION: 20.0
#       LINEAR_FRICTION: 0.5
#       MASS: 32.0
#       RADIUS: 0.1
#       SENSORS: ['DEPTH_SENSOR']
#       START_POSITION: [0, 0, 0]
#       START_ROTATION: [0, 0, 0, 1]
#     DEFAULT_AGENT_ID: 0
#     DEPTH_SENSOR:
#       HEIGHT: 256
#       HFOV: 90
#       MAX_DEPTH: 10.0
#       MIN_DEPTH: 0.0
#       NORMALIZE_DEPTH: True
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimDepthSensor
#       WIDTH: 256
#     FORWARD_STEP_SIZE: 0.25
#     HABITAT_SIM_V0:
#       ALLOW_SLIDING: True
#       ENABLE_PHYSICS: False
#       GPU_DEVICE_ID: 0
#       GPU_GPU: False
#       PHYSICS_CONFIG_FILE: ./data/default.phys_scene_config.json
#     RGB_SENSOR:
#       HEIGHT: 256
#       HFOV: 90
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimRGBSensor
#       WIDTH: 256
#     SCENE: data/scene_datasets/habitat-test-scenes/van-gogh-room.glb
#     SEED: 100
#     SEMANTIC_SENSOR:
#       HEIGHT: 480
#       HFOV: 90
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimSemanticSensor
#       WIDTH: 640
#     TILT_ANGLE: 15
#     TURN_ANGLE: 10
#     TYPE: Sim-v0
#   TASK:
#     ACTIONS:
#       ANSWER:
#         TYPE: AnswerAction
#       LOOK_DOWN:
#         TYPE: LookDownAction
#       LOOK_UP:
#         TYPE: LookUpAction
#       MOVE_FORWARD:
#         TYPE: MoveForwardAction
#       STOP:
#         TYPE: StopAction
#       TELEPORT:
#         TYPE: TeleportAction
#       TURN_LEFT:
#         TYPE: TurnLeftAction
#       TURN_RIGHT:
#         TYPE: TurnRightAction
#     ANSWER_ACCURACY:
#       TYPE: AnswerAccuracy
#     COLLISIONS:
#       TYPE: Collisions
#     COMPASS_SENSOR:
#       TYPE: CompassSensor
#     CORRECT_ANSWER:
#       TYPE: CorrectAnswer
#     DISTANCE_TO_GOAL:
#       DISTANCE_TO: POINT
#       TYPE: DistanceToGoal
#     EPISODE_INFO:
#       TYPE: EpisodeInfo
#     GOAL_SENSOR_UUID: pointgoal_with_gps_compass
#     GPS_SENSOR:
#       DIMENSIONALITY: 2
#       TYPE: GPSSensor
#     HEADING_SENSOR:
#       TYPE: HeadingSensor
#     INSTRUCTION_SENSOR:
#       TYPE: InstructionSensor
#     INSTRUCTION_SENSOR_UUID: instruction
#     MEASUREMENTS: ['DISTANCE_TO_GOAL', 'SPL']
#     OBJECTGOAL_SENSOR:
#       GOAL_SPEC: TASK_CATEGORY_ID
#       GOAL_SPEC_MAX_VAL: 50
#       TYPE: ObjectGoalSensor
#     POINTGOAL_SENSOR:
#       DIMENSIONALITY: 2
#       GOAL_FORMAT: POLAR
#       TYPE: PointGoalSensor
#     POINTGOAL_WITH_GPS_COMPASS_SENSOR:
#       DIMENSIONALITY: 2
#       GOAL_FORMAT: POLAR
#       TYPE: PointGoalWithGPSCompassSensor
#     POSSIBLE_ACTIONS: ['STOP', 'MOVE_FORWARD', 'TURN_LEFT', 'TURN_RIGHT']
#     PROXIMITY_SENSOR:
#       MAX_DETECTION_RADIUS: 2.0
#       TYPE: ProximitySensor
#     QUESTION_SENSOR:
#       TYPE: QuestionSensor
#     SENSORS: ['POINTGOAL_WITH_GPS_COMPASS_SENSOR']
#     SPL:
#       SUCCESS_DISTANCE: 0.2
#       TYPE: SPL
#     SUCCESS_DISTANCE: 0.2
#     TOP_DOWN_MAP:
#       DRAW_BORDER: True
#       DRAW_GOAL_AABBS: True
#       DRAW_GOAL_POSITIONS: True
#       DRAW_SHORTEST_PATH: True
#       DRAW_SOURCE: True
#       DRAW_VIEW_POINTS: True
#       FOG_OF_WAR:
#         DRAW: True
#         FOV: 90
#         VISIBILITY_DIST: 5.0
#       MAP_PADDING: 3
#       MAP_RESOLUTION: 1250
#       MAX_EPISODE_STEPS: 1000
#       NUM_TOPDOWN_MAP_SAMPLE_POINTS: 20000
#       TYPE: TopDownMap
#     TYPE: Nav-v0
# TENSORBOARD_DIR: tb
# TEST_EPISODE_COUNT: 994
# TORCH_GPU_ID: 0
# TRAINER_NAME: ddppo
# VIDEO_DIR: video_dir
# VIDEO_OPTION: []
# 2020-02-26 07:44:07,720 Initializing dataset PointNav-v1
# 2020-02-26 07:44:08,918 Initializing dataset PointNav-v1
# 2020-02-26 07:44:08,920 Initializing dataset PointNav-v1
# 2020-02-26 07:44:08,931 initializing sim Sim-v0
# 2020-02-26 07:44:08,933 initializing sim Sim-v0
# 2020-02-26 07:44:08,980 Initializing dataset PointNav-v1
# 2020-02-26 07:44:08,993 initializing sim Sim-v0
# 2020-02-26 07:44:08,996 Initializing dataset PointNav-v1
# 2020-02-26 07:44:09,009 initializing sim Sim-v0
# 2020-02-26 07:44:10,458 Initializing task Nav-v0
# 2020-02-26 07:44:13,400 Initializing task Nav-v0
# 2020-02-26 07:44:13,414 Initializing task Nav-v0
# 2020-02-26 07:44:13,592 Initializing task Nav-v0
# 2020-02-26 07:45:25,796 Average episode reward: 0.270680
# 2020-02-26 07:45:25,796 Average episode success: 1.000000
# 2020-02-26 07:45:25,796 Average episode distance_to_goal: 6.056786
# 2020-02-26 07:45:28,093 =======current_ckpt: data/new_checkpoints/ckpt.3.pth=======
# 2020-02-26 07:45:28,183 env config: BASE_TASK_CONFIG_PATH: configs/tasks/pointnav_gibson.yaml
# CHECKPOINT_FOLDER: data/new_checkpoints
# CHECKPOINT_INTERVAL: 50
# CMD_TRAILING_OPTS: []
# ENV_NAME: NavRLEnv
# EVAL:
#   SPLIT: val
#   USE_CKPT_CONFIG: True
# EVAL_CKPT_PATH_DIR: data/new_checkpoints
# LOG_FILE: train.log
# LOG_INTERVAL: 10
# NUM_PROCESSES: 4
# NUM_UPDATES: 10000
# ORBSLAM2:
#   ANGLE_TH: 0.2617993877991494
#   BETA: 100
#   CAMERA_HEIGHT: 1.25
#   DEPTH_DENORM: 10.0
#   DIST_REACHED_TH: 0.15
#   DIST_TO_STOP: 0.05
#   D_OBSTACLE_MAX: 4.0
#   D_OBSTACLE_MIN: 0.1
#   H_OBSTACLE_MAX: 1.25
#   H_OBSTACLE_MIN: 0.375
#   MAP_CELL_SIZE: 0.1
#   MAP_SIZE: 40
#   MIN_PTS_IN_OBSTACLE: 320.0
#   NEXT_WAYPOINT_TH: 0.5
#   NUM_ACTIONS: 3
#   PLANNER_MAX_STEPS: 500
#   PREPROCESS_MAP: True
#   SLAM_SETTINGS_PATH: habitat_baselines/slambased/data/mp3d3_small1k.yaml
#   SLAM_VOCAB_PATH: habitat_baselines/slambased/data/ORBvoc.txt
# RL:
#   DDPPO:
#     backbone: resnet50
#     distrib_backend: GLOO
#     num_recurrent_layers: 2
#     pretrained: False
#     pretrained_encoder: False
#     pretrained_weights: data/ddppo-models/gibson-2plus-resnet50.pth
#     reset_critic: True
#     rnn_type: LSTM
#     sync_frac: 0.6
#     train_encoder: True
#   PPO:
#     clip_param: 0.2
#     entropy_coef: 0.01
#     eps: 1e-05
#     gamma: 0.99
#     hidden_size: 512
#     lr: 0.00025
#     max_grad_norm: 0.2
#     num_mini_batch: 2
#     num_steps: 128
#     ppo_epoch: 2
#     reward_window_size: 50
#     tau: 0.95
#     use_gae: True
#     use_linear_clip_decay: False
#     use_linear_lr_decay: False
#     use_normalized_advantage: False
#     value_loss_coef: 0.5
#   REWARD_MEASURE: distance_to_goal
#   SLACK_REWARD: -0.01
#   SUCCESS_MEASURE: spl
#   SUCCESS_REWARD: 2.5
# SENSORS: ['DEPTH_SENSOR']
# SIMULATOR_GPU_ID: 0
# TASK_CONFIG:
#   DATASET:
#     CONTENT_SCENES: ['*']
#     DATA_PATH: data/datasets/pointnav/gibson/v1/{split}/{split}.json.gz
#     SCENES_DIR: data/scene_datasets
#     SPLIT: val
#     TYPE: PointNav-v1
#   ENVIRONMENT:
#     ITERATOR_OPTIONS:
#       CYCLE: True
#       GROUP_BY_SCENE: True
#       MAX_SCENE_REPEAT_EPISODES: -1
#       MAX_SCENE_REPEAT_STEPS: 10000
#       NUM_EPISODE_SAMPLE: -1
#       SHUFFLE: True
#       STEP_REPETITION_RANGE: 0.2
#     MAX_EPISODE_SECONDS: 10000000
#     MAX_EPISODE_STEPS: 500
#   PYROBOT:
#     BASE_CONTROLLER: proportional
#     BASE_PLANNER: none
#     BUMP_SENSOR:
#       TYPE: PyRobotBumpSensor
#     DEPTH_SENSOR:
#       CENTER_CROP: False
#       HEIGHT: 480
#       MAX_DEPTH: 5.0
#       MIN_DEPTH: 0.0
#       NORMALIZE_DEPTH: True
#       TYPE: PyRobotDepthSensor
#       WIDTH: 640
#     LOCOBOT:
#       ACTIONS: ['BASE_ACTIONS', 'CAMERA_ACTIONS']
#       BASE_ACTIONS: ['go_to_relative', 'go_to_absolute']
#       CAMERA_ACTIONS: ['set_pan', 'set_tilt', 'set_pan_tilt']
#     RGB_SENSOR:
#       CENTER_CROP: False
#       HEIGHT: 480
#       TYPE: PyRobotRGBSensor
#       WIDTH: 640
#     ROBOT: locobot
#     ROBOTS: ['locobot']
#     SENSORS: ['RGB_SENSOR', 'DEPTH_SENSOR', 'BUMP_SENSOR']
#   SEED: 100
#   SIMULATOR:
#     ACTION_SPACE_CONFIG: v0
#     AGENTS: ['AGENT_0']
#     AGENT_0:
#       ANGULAR_ACCELERATION: 12.56
#       ANGULAR_FRICTION: 1.0
#       COEFFICIENT_OF_RESTITUTION: 0.0
#       HEIGHT: 1.5
#       IS_SET_START_STATE: False
#       LINEAR_ACCELERATION: 20.0
#       LINEAR_FRICTION: 0.5
#       MASS: 32.0
#       RADIUS: 0.1
#       SENSORS: ['DEPTH_SENSOR']
#       START_POSITION: [0, 0, 0]
#       START_ROTATION: [0, 0, 0, 1]
#     DEFAULT_AGENT_ID: 0
#     DEPTH_SENSOR:
#       HEIGHT: 256
#       HFOV: 90
#       MAX_DEPTH: 10.0
#       MIN_DEPTH: 0.0
#       NORMALIZE_DEPTH: True
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimDepthSensor
#       WIDTH: 256
#     FORWARD_STEP_SIZE: 0.25
#     HABITAT_SIM_V0:
#       ALLOW_SLIDING: True
#       ENABLE_PHYSICS: False
#       GPU_DEVICE_ID: 0
#       GPU_GPU: False
#       PHYSICS_CONFIG_FILE: ./data/default.phys_scene_config.json
#     RGB_SENSOR:
#       HEIGHT: 256
#       HFOV: 90
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimRGBSensor
#       WIDTH: 256
#     SCENE: data/scene_datasets/habitat-test-scenes/van-gogh-room.glb
#     SEED: 100
#     SEMANTIC_SENSOR:
#       HEIGHT: 480
#       HFOV: 90
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimSemanticSensor
#       WIDTH: 640
#     TILT_ANGLE: 15
#     TURN_ANGLE: 10
#     TYPE: Sim-v0
#   TASK:
#     ACTIONS:
#       ANSWER:
#         TYPE: AnswerAction
#       LOOK_DOWN:
#         TYPE: LookDownAction
#       LOOK_UP:
#         TYPE: LookUpAction
#       MOVE_FORWARD:
#         TYPE: MoveForwardAction
#       STOP:
#         TYPE: StopAction
#       TELEPORT:
#         TYPE: TeleportAction
#       TURN_LEFT:
#         TYPE: TurnLeftAction
#       TURN_RIGHT:
#         TYPE: TurnRightAction
#     ANSWER_ACCURACY:
#       TYPE: AnswerAccuracy
#     COLLISIONS:
#       TYPE: Collisions
#     COMPASS_SENSOR:
#       TYPE: CompassSensor
#     CORRECT_ANSWER:
#       TYPE: CorrectAnswer
#     DISTANCE_TO_GOAL:
#       DISTANCE_TO: POINT
#       TYPE: DistanceToGoal
#     EPISODE_INFO:
#       TYPE: EpisodeInfo
#     GOAL_SENSOR_UUID: pointgoal_with_gps_compass
#     GPS_SENSOR:
#       DIMENSIONALITY: 2
#       TYPE: GPSSensor
#     HEADING_SENSOR:
#       TYPE: HeadingSensor
#     INSTRUCTION_SENSOR:
#       TYPE: InstructionSensor
#     INSTRUCTION_SENSOR_UUID: instruction
#     MEASUREMENTS: ['DISTANCE_TO_GOAL', 'SPL']
#     OBJECTGOAL_SENSOR:
#       GOAL_SPEC: TASK_CATEGORY_ID
#       GOAL_SPEC_MAX_VAL: 50
#       TYPE: ObjectGoalSensor
#     POINTGOAL_SENSOR:
#       DIMENSIONALITY: 2
#       GOAL_FORMAT: POLAR
#       TYPE: PointGoalSensor
#     POINTGOAL_WITH_GPS_COMPASS_SENSOR:
#       DIMENSIONALITY: 2
#       GOAL_FORMAT: POLAR
#       TYPE: PointGoalWithGPSCompassSensor
#     POSSIBLE_ACTIONS: ['STOP', 'MOVE_FORWARD', 'TURN_LEFT', 'TURN_RIGHT']
#     PROXIMITY_SENSOR:
#       MAX_DETECTION_RADIUS: 2.0
#       TYPE: ProximitySensor
#     QUESTION_SENSOR:
#       TYPE: QuestionSensor
#     SENSORS: ['POINTGOAL_WITH_GPS_COMPASS_SENSOR']
#     SPL:
#       SUCCESS_DISTANCE: 0.2
#       TYPE: SPL
#     SUCCESS_DISTANCE: 0.2
#     TOP_DOWN_MAP:
#       DRAW_BORDER: True
#       DRAW_GOAL_AABBS: True
#       DRAW_GOAL_POSITIONS: True
#       DRAW_SHORTEST_PATH: True
#       DRAW_SOURCE: True
#       DRAW_VIEW_POINTS: True
#       FOG_OF_WAR:
#         DRAW: True
#         FOV: 90
#         VISIBILITY_DIST: 5.0
#       MAP_PADDING: 3
#       MAP_RESOLUTION: 1250
#       MAX_EPISODE_STEPS: 1000
#       NUM_TOPDOWN_MAP_SAMPLE_POINTS: 20000
#       TYPE: TopDownMap
#     TYPE: Nav-v0
# TENSORBOARD_DIR: tb
# TEST_EPISODE_COUNT: 994
# TORCH_GPU_ID: 0
# TRAINER_NAME: ddppo
# VIDEO_DIR: video_dir
# VIDEO_OPTION: []
# 2020-02-26 07:45:28,184 Initializing dataset PointNav-v1
# 2020-02-26 07:45:29,393 Initializing dataset PointNav-v1
# 2020-02-26 07:45:29,401 Initializing dataset PointNav-v1
# 2020-02-26 07:45:29,402 Initializing dataset PointNav-v1
# 2020-02-26 07:45:29,406 initializing sim Sim-v0
# 2020-02-26 07:45:29,411 Initializing dataset PointNav-v1
# 2020-02-26 07:45:29,414 initializing sim Sim-v0
# 2020-02-26 07:45:29,415 initializing sim Sim-v0
# 2020-02-26 07:45:29,424 initializing sim Sim-v0
# 2020-02-26 07:45:33,774 Initializing task Nav-v0
# 2020-02-26 07:45:33,943 Initializing task Nav-v0
# 2020-02-26 07:45:34,214 Initializing task Nav-v0
# 2020-02-26 07:45:34,214 Initializing task Nav-v0
# 2020-02-26 07:46:25,897 Average episode reward: 0.204796
# 2020-02-26 07:46:25,897 Average episode success: 1.000000
# 2020-02-26 07:46:25,898 Average episode distance_to_goal: 5.611849
# 2020-02-26 07:46:28,230 =======current_ckpt: data/new_checkpoints/ckpt.4.pth=======
# 2020-02-26 07:46:28,299 env config: BASE_TASK_CONFIG_PATH: configs/tasks/pointnav_gibson.yaml
# CHECKPOINT_FOLDER: data/new_checkpoints
# CHECKPOINT_INTERVAL: 50
# CMD_TRAILING_OPTS: []
# ENV_NAME: NavRLEnv
# EVAL:
#   SPLIT: val
#   USE_CKPT_CONFIG: True
# EVAL_CKPT_PATH_DIR: data/new_checkpoints
# LOG_FILE: train.log
# LOG_INTERVAL: 10
# NUM_PROCESSES: 4
# NUM_UPDATES: 10000
# ORBSLAM2:
#   ANGLE_TH: 0.2617993877991494
#   BETA: 100
#   CAMERA_HEIGHT: 1.25
#   DEPTH_DENORM: 10.0
#   DIST_REACHED_TH: 0.15
#   DIST_TO_STOP: 0.05
#   D_OBSTACLE_MAX: 4.0
#   D_OBSTACLE_MIN: 0.1
#   H_OBSTACLE_MAX: 1.25
#   H_OBSTACLE_MIN: 0.375
#   MAP_CELL_SIZE: 0.1
#   MAP_SIZE: 40
#   MIN_PTS_IN_OBSTACLE: 320.0
#   NEXT_WAYPOINT_TH: 0.5
#   NUM_ACTIONS: 3
#   PLANNER_MAX_STEPS: 500
#   PREPROCESS_MAP: True
#   SLAM_SETTINGS_PATH: habitat_baselines/slambased/data/mp3d3_small1k.yaml
#   SLAM_VOCAB_PATH: habitat_baselines/slambased/data/ORBvoc.txt
# RL:
#   DDPPO:
#     backbone: resnet50
#     distrib_backend: GLOO
#     num_recurrent_layers: 2
#     pretrained: False
#     pretrained_encoder: False
#     pretrained_weights: data/ddppo-models/gibson-2plus-resnet50.pth
#     reset_critic: True
#     rnn_type: LSTM
#     sync_frac: 0.6
#     train_encoder: True
#   PPO:
#     clip_param: 0.2
#     entropy_coef: 0.01
#     eps: 1e-05
#     gamma: 0.99
#     hidden_size: 512
#     lr: 0.00025
#     max_grad_norm: 0.2
#     num_mini_batch: 2
#     num_steps: 128
#     ppo_epoch: 2
#     reward_window_size: 50
#     tau: 0.95
#     use_gae: True
#     use_linear_clip_decay: False
#     use_linear_lr_decay: False
#     use_normalized_advantage: False
#     value_loss_coef: 0.5
#   REWARD_MEASURE: distance_to_goal
#   SLACK_REWARD: -0.01
#   SUCCESS_MEASURE: spl
#   SUCCESS_REWARD: 2.5
# SENSORS: ['DEPTH_SENSOR']
# SIMULATOR_GPU_ID: 0
# TASK_CONFIG:
#   DATASET:
#     CONTENT_SCENES: ['*']
#     DATA_PATH: data/datasets/pointnav/gibson/v1/{split}/{split}.json.gz
#     SCENES_DIR: data/scene_datasets
#     SPLIT: val
#     TYPE: PointNav-v1
#   ENVIRONMENT:
#     ITERATOR_OPTIONS:
#       CYCLE: True
#       GROUP_BY_SCENE: True
#       MAX_SCENE_REPEAT_EPISODES: -1
#       MAX_SCENE_REPEAT_STEPS: 10000
#       NUM_EPISODE_SAMPLE: -1
#       SHUFFLE: True
#       STEP_REPETITION_RANGE: 0.2
#     MAX_EPISODE_SECONDS: 10000000
#     MAX_EPISODE_STEPS: 500
#   PYROBOT:
#     BASE_CONTROLLER: proportional
#     BASE_PLANNER: none
#     BUMP_SENSOR:
#       TYPE: PyRobotBumpSensor
#     DEPTH_SENSOR:
#       CENTER_CROP: False
#       HEIGHT: 480
#       MAX_DEPTH: 5.0
#       MIN_DEPTH: 0.0
#       NORMALIZE_DEPTH: True
#       TYPE: PyRobotDepthSensor
#       WIDTH: 640
#     LOCOBOT:
#       ACTIONS: ['BASE_ACTIONS', 'CAMERA_ACTIONS']
#       BASE_ACTIONS: ['go_to_relative', 'go_to_absolute']
#       CAMERA_ACTIONS: ['set_pan', 'set_tilt', 'set_pan_tilt']
#     RGB_SENSOR:
#       CENTER_CROP: False
#       HEIGHT: 480
#       TYPE: PyRobotRGBSensor
#       WIDTH: 640
#     ROBOT: locobot
#     ROBOTS: ['locobot']
#     SENSORS: ['RGB_SENSOR', 'DEPTH_SENSOR', 'BUMP_SENSOR']
#   SEED: 100
#   SIMULATOR:
#     ACTION_SPACE_CONFIG: v0
#     AGENTS: ['AGENT_0']
#     AGENT_0:
#       ANGULAR_ACCELERATION: 12.56
#       ANGULAR_FRICTION: 1.0
#       COEFFICIENT_OF_RESTITUTION: 0.0
#       HEIGHT: 1.5
#       IS_SET_START_STATE: False
#       LINEAR_ACCELERATION: 20.0
#       LINEAR_FRICTION: 0.5
#       MASS: 32.0
#       RADIUS: 0.1
#       SENSORS: ['DEPTH_SENSOR']
#       START_POSITION: [0, 0, 0]
#       START_ROTATION: [0, 0, 0, 1]
#     DEFAULT_AGENT_ID: 0
#     DEPTH_SENSOR:
#       HEIGHT: 256
#       HFOV: 90
#       MAX_DEPTH: 10.0
#       MIN_DEPTH: 0.0
#       NORMALIZE_DEPTH: True
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimDepthSensor
#       WIDTH: 256
#     FORWARD_STEP_SIZE: 0.25
#     HABITAT_SIM_V0:
#       ALLOW_SLIDING: True
#       ENABLE_PHYSICS: False
#       GPU_DEVICE_ID: 0
#       GPU_GPU: False
#       PHYSICS_CONFIG_FILE: ./data/default.phys_scene_config.json
#     RGB_SENSOR:
#       HEIGHT: 256
#       HFOV: 90
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimRGBSensor
#       WIDTH: 256
#     SCENE: data/scene_datasets/habitat-test-scenes/van-gogh-room.glb
#     SEED: 100
#     SEMANTIC_SENSOR:
#       HEIGHT: 480
#       HFOV: 90
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimSemanticSensor
#       WIDTH: 640
#     TILT_ANGLE: 15
#     TURN_ANGLE: 10
#     TYPE: Sim-v0
#   TASK:
#     ACTIONS:
#       ANSWER:
#         TYPE: AnswerAction
#       LOOK_DOWN:
#         TYPE: LookDownAction
#       LOOK_UP:
#         TYPE: LookUpAction
#       MOVE_FORWARD:
#         TYPE: MoveForwardAction
#       STOP:
#         TYPE: StopAction
#       TELEPORT:
#         TYPE: TeleportAction
#       TURN_LEFT:
#         TYPE: TurnLeftAction
#       TURN_RIGHT:
#         TYPE: TurnRightAction
#     ANSWER_ACCURACY:
#       TYPE: AnswerAccuracy
#     COLLISIONS:
#       TYPE: Collisions
#     COMPASS_SENSOR:
#       TYPE: CompassSensor
#     CORRECT_ANSWER:
#       TYPE: CorrectAnswer
#     DISTANCE_TO_GOAL:
#       DISTANCE_TO: POINT
#       TYPE: DistanceToGoal
#     EPISODE_INFO:
#       TYPE: EpisodeInfo
#     GOAL_SENSOR_UUID: pointgoal_with_gps_compass
#     GPS_SENSOR:
#       DIMENSIONALITY: 2
#       TYPE: GPSSensor
#     HEADING_SENSOR:
#       TYPE: HeadingSensor
#     INSTRUCTION_SENSOR:
#       TYPE: InstructionSensor
#     INSTRUCTION_SENSOR_UUID: instruction
#     MEASUREMENTS: ['DISTANCE_TO_GOAL', 'SPL']
#     OBJECTGOAL_SENSOR:
#       GOAL_SPEC: TASK_CATEGORY_ID
#       GOAL_SPEC_MAX_VAL: 50
#       TYPE: ObjectGoalSensor
#     POINTGOAL_SENSOR:
#       DIMENSIONALITY: 2
#       GOAL_FORMAT: POLAR
#       TYPE: PointGoalSensor
#     POINTGOAL_WITH_GPS_COMPASS_SENSOR:
#       DIMENSIONALITY: 2
#       GOAL_FORMAT: POLAR
#       TYPE: PointGoalWithGPSCompassSensor
#     POSSIBLE_ACTIONS: ['STOP', 'MOVE_FORWARD', 'TURN_LEFT', 'TURN_RIGHT']
#     PROXIMITY_SENSOR:
#       MAX_DETECTION_RADIUS: 2.0
#       TYPE: ProximitySensor
#     QUESTION_SENSOR:
#       TYPE: QuestionSensor
#     SENSORS: ['POINTGOAL_WITH_GPS_COMPASS_SENSOR']
#     SPL:
#       SUCCESS_DISTANCE: 0.2
#       TYPE: SPL
#     SUCCESS_DISTANCE: 0.2
#     TOP_DOWN_MAP:
#       DRAW_BORDER: True
#       DRAW_GOAL_AABBS: True
#       DRAW_GOAL_POSITIONS: True
#       DRAW_SHORTEST_PATH: True
#       DRAW_SOURCE: True
#       DRAW_VIEW_POINTS: True
#       FOG_OF_WAR:
#         DRAW: True
#         FOV: 90
#         VISIBILITY_DIST: 5.0
#       MAP_PADDING: 3
#       MAP_RESOLUTION: 1250
#       MAX_EPISODE_STEPS: 1000
#       NUM_TOPDOWN_MAP_SAMPLE_POINTS: 20000
#       TYPE: TopDownMap
#     TYPE: Nav-v0
# TENSORBOARD_DIR: tb
# TEST_EPISODE_COUNT: 994
# TORCH_GPU_ID: 0
# TRAINER_NAME: ddppo
# VIDEO_DIR: video_dir
# VIDEO_OPTION: []
# 2020-02-26 07:46:28,299 Initializing dataset PointNav-v1
# 2020-02-26 07:46:29,473 Initializing dataset PointNav-v1
# 2020-02-26 07:46:29,486 initializing sim Sim-v0
# 2020-02-26 07:46:29,489 Initializing dataset PointNav-v1
# 2020-02-26 07:46:29,489 Initializing dataset PointNav-v1
# 2020-02-26 07:46:29,502 initializing sim Sim-v0
# 2020-02-26 07:46:29,502 initializing sim Sim-v0
# 2020-02-26 07:46:29,510 Initializing dataset PointNav-v1
# 2020-02-26 07:46:29,530 initializing sim Sim-v0
# 2020-02-26 07:46:30,941 Initializing task Nav-v0
# 2020-02-26 07:46:34,145 Initializing task Nav-v0
# 2020-02-26 07:46:34,279 Initializing task Nav-v0
# 2020-02-26 07:46:34,319 Initializing task Nav-v0
# 2020-02-26 07:50:05,053 Average episode reward: 0.712467
# 2020-02-26 07:50:05,054 Average episode success: 1.000000
# 2020-02-26 07:50:05,054 Average episode distance_to_goal: 5.107430
# 2020-02-26 07:50:07,346 =======current_ckpt: data/new_checkpoints/ckpt.5.pth=======
# 2020-02-26 07:50:07,414 env config: BASE_TASK_CONFIG_PATH: configs/tasks/pointnav_gibson.yaml
# CHECKPOINT_FOLDER: data/new_checkpoints
# CHECKPOINT_INTERVAL: 50
# CMD_TRAILING_OPTS: []
# ENV_NAME: NavRLEnv
# EVAL:
#   SPLIT: val
#   USE_CKPT_CONFIG: True
# EVAL_CKPT_PATH_DIR: data/new_checkpoints
# LOG_FILE: train.log
# LOG_INTERVAL: 10
# NUM_PROCESSES: 4
# NUM_UPDATES: 10000
# ORBSLAM2:
#   ANGLE_TH: 0.2617993877991494
#   BETA: 100
#   CAMERA_HEIGHT: 1.25
#   DEPTH_DENORM: 10.0
#   DIST_REACHED_TH: 0.15
#   DIST_TO_STOP: 0.05
#   D_OBSTACLE_MAX: 4.0
#   D_OBSTACLE_MIN: 0.1
#   H_OBSTACLE_MAX: 1.25
#   H_OBSTACLE_MIN: 0.375
#   MAP_CELL_SIZE: 0.1
#   MAP_SIZE: 40
#   MIN_PTS_IN_OBSTACLE: 320.0
#   NEXT_WAYPOINT_TH: 0.5
#   NUM_ACTIONS: 3
#   PLANNER_MAX_STEPS: 500
#   PREPROCESS_MAP: True
#   SLAM_SETTINGS_PATH: habitat_baselines/slambased/data/mp3d3_small1k.yaml
#   SLAM_VOCAB_PATH: habitat_baselines/slambased/data/ORBvoc.txt
# RL:
#   DDPPO:
#     backbone: resnet50
#     distrib_backend: GLOO
#     num_recurrent_layers: 2
#     pretrained: False
#     pretrained_encoder: False
#     pretrained_weights: data/ddppo-models/gibson-2plus-resnet50.pth
#     reset_critic: True
#     rnn_type: LSTM
#     sync_frac: 0.6
#     train_encoder: True
#   PPO:
#     clip_param: 0.2
#     entropy_coef: 0.01
#     eps: 1e-05
#     gamma: 0.99
#     hidden_size: 512
#     lr: 0.00025
#     max_grad_norm: 0.2
#     num_mini_batch: 2
#     num_steps: 128
#     ppo_epoch: 2
#     reward_window_size: 50
#     tau: 0.95
#     use_gae: True
#     use_linear_clip_decay: False
#     use_linear_lr_decay: False
#     use_normalized_advantage: False
#     value_loss_coef: 0.5
#   REWARD_MEASURE: distance_to_goal
#   SLACK_REWARD: -0.01
#   SUCCESS_MEASURE: spl
#   SUCCESS_REWARD: 2.5
# SENSORS: ['DEPTH_SENSOR']
# SIMULATOR_GPU_ID: 0
# TASK_CONFIG:
#   DATASET:
#     CONTENT_SCENES: ['*']
#     DATA_PATH: data/datasets/pointnav/gibson/v1/{split}/{split}.json.gz
#     SCENES_DIR: data/scene_datasets
#     SPLIT: val
#     TYPE: PointNav-v1
#   ENVIRONMENT:
#     ITERATOR_OPTIONS:
#       CYCLE: True
#       GROUP_BY_SCENE: True
#       MAX_SCENE_REPEAT_EPISODES: -1
#       MAX_SCENE_REPEAT_STEPS: 10000
#       NUM_EPISODE_SAMPLE: -1
#       SHUFFLE: True
#       STEP_REPETITION_RANGE: 0.2
#     MAX_EPISODE_SECONDS: 10000000
#     MAX_EPISODE_STEPS: 500
#   PYROBOT:
#     BASE_CONTROLLER: proportional
#     BASE_PLANNER: none
#     BUMP_SENSOR:
#       TYPE: PyRobotBumpSensor
#     DEPTH_SENSOR:
#       CENTER_CROP: False
#       HEIGHT: 480
#       MAX_DEPTH: 5.0
#       MIN_DEPTH: 0.0
#       NORMALIZE_DEPTH: True
#       TYPE: PyRobotDepthSensor
#       WIDTH: 640
#     LOCOBOT:
#       ACTIONS: ['BASE_ACTIONS', 'CAMERA_ACTIONS']
#       BASE_ACTIONS: ['go_to_relative', 'go_to_absolute']
#       CAMERA_ACTIONS: ['set_pan', 'set_tilt', 'set_pan_tilt']
#     RGB_SENSOR:
#       CENTER_CROP: False
#       HEIGHT: 480
#       TYPE: PyRobotRGBSensor
#       WIDTH: 640
#     ROBOT: locobot
#     ROBOTS: ['locobot']
#     SENSORS: ['RGB_SENSOR', 'DEPTH_SENSOR', 'BUMP_SENSOR']
#   SEED: 100
#   SIMULATOR:
#     ACTION_SPACE_CONFIG: v0
#     AGENTS: ['AGENT_0']
#     AGENT_0:
#       ANGULAR_ACCELERATION: 12.56
#       ANGULAR_FRICTION: 1.0
#       COEFFICIENT_OF_RESTITUTION: 0.0
#       HEIGHT: 1.5
#       IS_SET_START_STATE: False
#       LINEAR_ACCELERATION: 20.0
#       LINEAR_FRICTION: 0.5
# ...
#     TOP_DOWN_MAP:
#       DRAW_BORDER: True
#       DRAW_GOAL_AABBS: True
#       DRAW_GOAL_POSITIONS: True
#       DRAW_SHORTEST_PATH: True
#       DRAW_SOURCE: True
#       DRAW_VIEW_POINTS: True
#       FOG_OF_WAR:
#         DRAW: True
#         FOV: 90
#         VISIBILITY_DIST: 5.0
#       MAP_PADDING: 3
#       MAP_RESOLUTION: 1250
#       MAX_EPISODE_STEPS: 1000
#       NUM_TOPDOWN_MAP_SAMPLE_POINTS: 20000
#       TYPE: TopDownMap
#     TYPE: Nav-v0
# TENSORBOARD_DIR: tb
# TEST_EPISODE_COUNT: 994
# TORCH_GPU_ID: 0
# TRAINER_NAME: ddppo
# VIDEO_DIR: video_dir
# VIDEO_OPTION: []
# 2020-02-27 05:27:42,885 Initializing dataset PointNav-v1
# 2020-02-27 05:27:44,089 Initializing dataset PointNav-v1
# 2020-02-27 05:27:44,093 Initializing dataset PointNav-v1
# 2020-02-27 05:27:44,093 Initializing dataset PointNav-v1
# 2020-02-27 05:27:44,102 initializing sim Sim-v0
# 2020-02-27 05:27:44,106 initializing sim Sim-v0
# 2020-02-27 05:27:44,106 initializing sim Sim-v0
# 2020-02-27 05:27:44,106 Initializing dataset PointNav-v1
# 2020-02-27 05:27:44,120 initializing sim Sim-v0
# 2020-02-27 05:27:49,045 Initializing task Nav-v0
# 2020-02-27 05:27:49,075 Initializing task Nav-v0
# 2020-02-27 05:27:49,097 Initializing task Nav-v0
# 2020-02-27 05:27:49,251 Initializing task Nav-v0
# 2020-02-27 05:35:25,715 Average episode reward: 5.472494
# 2020-02-27 05:35:25,721 Average episode success: 1.000000
# 2020-02-27 05:35:25,725 Average episode distance_to_goal: 0.790178
# 2020-02-27 05:35:28,060 =======current_ckpt: data/new_checkpoints/ckpt.198.pth=======
# 2020-02-27 05:35:28,133 env config: BASE_TASK_CONFIG_PATH: configs/tasks/pointnav_gibson.yaml
# CHECKPOINT_FOLDER: data/new_checkpoints
# CHECKPOINT_INTERVAL: 50
# CMD_TRAILING_OPTS: []
# ENV_NAME: NavRLEnv
# EVAL:
#   SPLIT: val
#   USE_CKPT_CONFIG: True
# EVAL_CKPT_PATH_DIR: data/new_checkpoints
# LOG_FILE: train.log
# LOG_INTERVAL: 10
# NUM_PROCESSES: 4
# NUM_UPDATES: 10000
# ORBSLAM2:
#   ANGLE_TH: 0.2617993877991494
#   BETA: 100
#   CAMERA_HEIGHT: 1.25
#   DEPTH_DENORM: 10.0
#   DIST_REACHED_TH: 0.15
#   DIST_TO_STOP: 0.05
#   D_OBSTACLE_MAX: 4.0
#   D_OBSTACLE_MIN: 0.1
#   H_OBSTACLE_MAX: 1.25
#   H_OBSTACLE_MIN: 0.375
#   MAP_CELL_SIZE: 0.1
#   MAP_SIZE: 40
#   MIN_PTS_IN_OBSTACLE: 320.0
#   NEXT_WAYPOINT_TH: 0.5
#   NUM_ACTIONS: 3
#   PLANNER_MAX_STEPS: 500
#   PREPROCESS_MAP: True
#   SLAM_SETTINGS_PATH: habitat_baselines/slambased/data/mp3d3_small1k.yaml
#   SLAM_VOCAB_PATH: habitat_baselines/slambased/data/ORBvoc.txt
# RL:
#   DDPPO:
#     backbone: resnet50
#     distrib_backend: GLOO
#     num_recurrent_layers: 2
#     pretrained: False
#     pretrained_encoder: False
#     pretrained_weights: data/ddppo-models/gibson-2plus-resnet50.pth
#     reset_critic: True
#     rnn_type: LSTM
#     sync_frac: 0.6
#     train_encoder: True
#   PPO:
#     clip_param: 0.2
#     entropy_coef: 0.01
#     eps: 1e-05
#     gamma: 0.99
#     hidden_size: 512
#     lr: 0.00025
#     max_grad_norm: 0.2
#     num_mini_batch: 2
#     num_steps: 128
#     ppo_epoch: 2
#     reward_window_size: 50
#     tau: 0.95
#     use_gae: True
#     use_linear_clip_decay: False
#     use_linear_lr_decay: False
#     use_normalized_advantage: False
#     value_loss_coef: 0.5
#   REWARD_MEASURE: distance_to_goal
#   SLACK_REWARD: -0.01
#   SUCCESS_MEASURE: spl
#   SUCCESS_REWARD: 2.5
# SENSORS: ['DEPTH_SENSOR']
# SIMULATOR_GPU_ID: 0
# TASK_CONFIG:
#   DATASET:
#     CONTENT_SCENES: ['*']
#     DATA_PATH: data/datasets/pointnav/gibson/v1/{split}/{split}.json.gz
#     SCENES_DIR: data/scene_datasets
#     SPLIT: val
#     TYPE: PointNav-v1
#   ENVIRONMENT:
#     ITERATOR_OPTIONS:
#       CYCLE: True
#       GROUP_BY_SCENE: True
#       MAX_SCENE_REPEAT_EPISODES: -1
#       MAX_SCENE_REPEAT_STEPS: 10000
#       NUM_EPISODE_SAMPLE: -1
#       SHUFFLE: True
#       STEP_REPETITION_RANGE: 0.2
#     MAX_EPISODE_SECONDS: 10000000
#     MAX_EPISODE_STEPS: 500
#   PYROBOT:
#     BASE_CONTROLLER: proportional
#     BASE_PLANNER: none
#     BUMP_SENSOR:
#       TYPE: PyRobotBumpSensor
#     DEPTH_SENSOR:
#       CENTER_CROP: False
#       HEIGHT: 480
#       MAX_DEPTH: 5.0
#       MIN_DEPTH: 0.0
#       NORMALIZE_DEPTH: True
#       TYPE: PyRobotDepthSensor
#       WIDTH: 640
#     LOCOBOT:
#       ACTIONS: ['BASE_ACTIONS', 'CAMERA_ACTIONS']
#       BASE_ACTIONS: ['go_to_relative', 'go_to_absolute']
#       CAMERA_ACTIONS: ['set_pan', 'set_tilt', 'set_pan_tilt']
#     RGB_SENSOR:
#       CENTER_CROP: False
#       HEIGHT: 480
#       TYPE: PyRobotRGBSensor
#       WIDTH: 640
#     ROBOT: locobot
#     ROBOTS: ['locobot']
#     SENSORS: ['RGB_SENSOR', 'DEPTH_SENSOR', 'BUMP_SENSOR']
#   SEED: 100
#   SIMULATOR:
#     ACTION_SPACE_CONFIG: v0
#     AGENTS: ['AGENT_0']
#     AGENT_0:
#       ANGULAR_ACCELERATION: 12.56
#       ANGULAR_FRICTION: 1.0
#       COEFFICIENT_OF_RESTITUTION: 0.0
#       HEIGHT: 1.5
#       IS_SET_START_STATE: False
#       LINEAR_ACCELERATION: 20.0
#       LINEAR_FRICTION: 0.5
#       MASS: 32.0
#       RADIUS: 0.1
#       SENSORS: ['DEPTH_SENSOR']
#       START_POSITION: [0, 0, 0]
#       START_ROTATION: [0, 0, 0, 1]
#     DEFAULT_AGENT_ID: 0
#     DEPTH_SENSOR:
#       HEIGHT: 256
#       HFOV: 90
#       MAX_DEPTH: 10.0
#       MIN_DEPTH: 0.0
#       NORMALIZE_DEPTH: True
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimDepthSensor
#       WIDTH: 256
#     FORWARD_STEP_SIZE: 0.25
#     HABITAT_SIM_V0:
#       ALLOW_SLIDING: True
#       ENABLE_PHYSICS: False
#       GPU_DEVICE_ID: 0
#       GPU_GPU: False
#       PHYSICS_CONFIG_FILE: ./data/default.phys_scene_config.json
#     RGB_SENSOR:
#       HEIGHT: 256
#       HFOV: 90
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimRGBSensor
#       WIDTH: 256
#     SCENE: data/scene_datasets/habitat-test-scenes/van-gogh-room.glb
#     SEED: 100
#     SEMANTIC_SENSOR:
#       HEIGHT: 480
#       HFOV: 90
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimSemanticSensor
#       WIDTH: 640
#     TILT_ANGLE: 15
#     TURN_ANGLE: 10
#     TYPE: Sim-v0
#   TASK:
#     ACTIONS:
#       ANSWER:
#         TYPE: AnswerAction
#       LOOK_DOWN:
#         TYPE: LookDownAction
#       LOOK_UP:
#         TYPE: LookUpAction
#       MOVE_FORWARD:
#         TYPE: MoveForwardAction
#       STOP:
#         TYPE: StopAction
#       TELEPORT:
#         TYPE: TeleportAction
#       TURN_LEFT:
#         TYPE: TurnLeftAction
#       TURN_RIGHT:
#         TYPE: TurnRightAction
#     ANSWER_ACCURACY:
#       TYPE: AnswerAccuracy
#     COLLISIONS:
#       TYPE: Collisions
#     COMPASS_SENSOR:
#       TYPE: CompassSensor
#     CORRECT_ANSWER:
#       TYPE: CorrectAnswer
#     DISTANCE_TO_GOAL:
#       DISTANCE_TO: POINT
#       TYPE: DistanceToGoal
#     EPISODE_INFO:
#       TYPE: EpisodeInfo
#     GOAL_SENSOR_UUID: pointgoal_with_gps_compass
#     GPS_SENSOR:
#       DIMENSIONALITY: 2
#       TYPE: GPSSensor
#     HEADING_SENSOR:
#       TYPE: HeadingSensor
#     INSTRUCTION_SENSOR:
#       TYPE: InstructionSensor
#     INSTRUCTION_SENSOR_UUID: instruction
#     MEASUREMENTS: ['DISTANCE_TO_GOAL', 'SPL']
#     OBJECTGOAL_SENSOR:
#       GOAL_SPEC: TASK_CATEGORY_ID
#       GOAL_SPEC_MAX_VAL: 50
#       TYPE: ObjectGoalSensor
#     POINTGOAL_SENSOR:
#       DIMENSIONALITY: 2
#       GOAL_FORMAT: POLAR
#       TYPE: PointGoalSensor
#     POINTGOAL_WITH_GPS_COMPASS_SENSOR:
#       DIMENSIONALITY: 2
#       GOAL_FORMAT: POLAR
#       TYPE: PointGoalWithGPSCompassSensor
#     POSSIBLE_ACTIONS: ['STOP', 'MOVE_FORWARD', 'TURN_LEFT', 'TURN_RIGHT']
#     PROXIMITY_SENSOR:
#       MAX_DETECTION_RADIUS: 2.0
#       TYPE: ProximitySensor
#     QUESTION_SENSOR:
#       TYPE: QuestionSensor
#     SENSORS: ['POINTGOAL_WITH_GPS_COMPASS_SENSOR']
#     SPL:
#       SUCCESS_DISTANCE: 0.2
#       TYPE: SPL
#     SUCCESS_DISTANCE: 0.2
#     TOP_DOWN_MAP:
#       DRAW_BORDER: True
#       DRAW_GOAL_AABBS: True
#       DRAW_GOAL_POSITIONS: True
#       DRAW_SHORTEST_PATH: True
#       DRAW_SOURCE: True
#       DRAW_VIEW_POINTS: True
#       FOG_OF_WAR:
#         DRAW: True
#         FOV: 90
#         VISIBILITY_DIST: 5.0
#       MAP_PADDING: 3
#       MAP_RESOLUTION: 1250
#       MAX_EPISODE_STEPS: 1000
#       NUM_TOPDOWN_MAP_SAMPLE_POINTS: 20000
#       TYPE: TopDownMap
#     TYPE: Nav-v0
# TENSORBOARD_DIR: tb
# TEST_EPISODE_COUNT: 994
# TORCH_GPU_ID: 0
# TRAINER_NAME: ddppo
# VIDEO_DIR: video_dir
# VIDEO_OPTION: []
# 2020-02-27 05:35:28,136 Initializing dataset PointNav-v1
# 2020-02-27 05:35:29,350 Initializing dataset PointNav-v1
# 2020-02-27 05:35:29,357 Initializing dataset PointNav-v1
# 2020-02-27 05:35:29,363 initializing sim Sim-v0
# 2020-02-27 05:35:29,369 initializing sim Sim-v0
# 2020-02-27 05:35:29,387 Initializing dataset PointNav-v1
# 2020-02-27 05:35:29,388 Initializing dataset PointNav-v1
# 2020-02-27 05:35:29,401 initializing sim Sim-v0
# 2020-02-27 05:35:29,402 initializing sim Sim-v0
# 2020-02-27 05:35:30,869 Initializing task Nav-v0
# 2020-02-27 05:35:31,015 Initializing task Nav-v0
# 2020-02-27 05:35:31,054 Initializing task Nav-v0
# 2020-02-27 05:35:33,548 Initializing task Nav-v0
# 2020-02-27 05:42:39,828 Average episode reward: 5.325642
# 2020-02-27 05:42:39,834 Average episode success: 1.000000
# 2020-02-27 05:42:39,839 Average episode distance_to_goal: 0.686504
# 2020-02-27 05:42:42,113 =======current_ckpt: data/new_checkpoints/ckpt.199.pth=======
# 2020-02-27 05:42:42,307 env config: BASE_TASK_CONFIG_PATH: configs/tasks/pointnav_gibson.yaml
# CHECKPOINT_FOLDER: data/new_checkpoints
# CHECKPOINT_INTERVAL: 50
# CMD_TRAILING_OPTS: []
# ENV_NAME: NavRLEnv
# EVAL:
#   SPLIT: val
#   USE_CKPT_CONFIG: True
# EVAL_CKPT_PATH_DIR: data/new_checkpoints
# LOG_FILE: train.log
# LOG_INTERVAL: 10
# NUM_PROCESSES: 4
# NUM_UPDATES: 10000
# ORBSLAM2:
#   ANGLE_TH: 0.2617993877991494
#   BETA: 100
#   CAMERA_HEIGHT: 1.25
#   DEPTH_DENORM: 10.0
#   DIST_REACHED_TH: 0.15
#   DIST_TO_STOP: 0.05
#   D_OBSTACLE_MAX: 4.0
#   D_OBSTACLE_MIN: 0.1
#   H_OBSTACLE_MAX: 1.25
#   H_OBSTACLE_MIN: 0.375
#   MAP_CELL_SIZE: 0.1
#   MAP_SIZE: 40
#   MIN_PTS_IN_OBSTACLE: 320.0
#   NEXT_WAYPOINT_TH: 0.5
#   NUM_ACTIONS: 3
#   PLANNER_MAX_STEPS: 500
#   PREPROCESS_MAP: True
#   SLAM_SETTINGS_PATH: habitat_baselines/slambased/data/mp3d3_small1k.yaml
#   SLAM_VOCAB_PATH: habitat_baselines/slambased/data/ORBvoc.txt
# RL:
#   DDPPO:
#     backbone: resnet50
#     distrib_backend: GLOO
#     num_recurrent_layers: 2
#     pretrained: False
#     pretrained_encoder: False
#     pretrained_weights: data/ddppo-models/gibson-2plus-resnet50.pth
#     reset_critic: True
#     rnn_type: LSTM
#     sync_frac: 0.6
#     train_encoder: True
#   PPO:
#     clip_param: 0.2
#     entropy_coef: 0.01
#     eps: 1e-05
#     gamma: 0.99
#     hidden_size: 512
#     lr: 0.00025
#     max_grad_norm: 0.2
#     num_mini_batch: 2
#     num_steps: 128
#     ppo_epoch: 2
#     reward_window_size: 50
#     tau: 0.95
#     use_gae: True
#     use_linear_clip_decay: False
#     use_linear_lr_decay: False
#     use_normalized_advantage: False
#     value_loss_coef: 0.5
#   REWARD_MEASURE: distance_to_goal
#   SLACK_REWARD: -0.01
#   SUCCESS_MEASURE: spl
#   SUCCESS_REWARD: 2.5
# SENSORS: ['DEPTH_SENSOR']
# SIMULATOR_GPU_ID: 0
# TASK_CONFIG:
#   DATASET:
#     CONTENT_SCENES: ['*']
#     DATA_PATH: data/datasets/pointnav/gibson/v1/{split}/{split}.json.gz
#     SCENES_DIR: data/scene_datasets
#     SPLIT: val
#     TYPE: PointNav-v1
#   ENVIRONMENT:
#     ITERATOR_OPTIONS:
#       CYCLE: True
#       GROUP_BY_SCENE: True
#       MAX_SCENE_REPEAT_EPISODES: -1
#       MAX_SCENE_REPEAT_STEPS: 10000
#       NUM_EPISODE_SAMPLE: -1
#       SHUFFLE: True
#       STEP_REPETITION_RANGE: 0.2
#     MAX_EPISODE_SECONDS: 10000000
#     MAX_EPISODE_STEPS: 500
#   PYROBOT:
#     BASE_CONTROLLER: proportional
#     BASE_PLANNER: none
#     BUMP_SENSOR:
#       TYPE: PyRobotBumpSensor
#     DEPTH_SENSOR:
#       CENTER_CROP: False
#       HEIGHT: 480
#       MAX_DEPTH: 5.0
#       MIN_DEPTH: 0.0
#       NORMALIZE_DEPTH: True
#       TYPE: PyRobotDepthSensor
#       WIDTH: 640
#     LOCOBOT:
#       ACTIONS: ['BASE_ACTIONS', 'CAMERA_ACTIONS']
#       BASE_ACTIONS: ['go_to_relative', 'go_to_absolute']
#       CAMERA_ACTIONS: ['set_pan', 'set_tilt', 'set_pan_tilt']
#     RGB_SENSOR:
#       CENTER_CROP: False
#       HEIGHT: 480
#       TYPE: PyRobotRGBSensor
#       WIDTH: 640
#     ROBOT: locobot
#     ROBOTS: ['locobot']
#     SENSORS: ['RGB_SENSOR', 'DEPTH_SENSOR', 'BUMP_SENSOR']
#   SEED: 100
#   SIMULATOR:
#     ACTION_SPACE_CONFIG: v0
#     AGENTS: ['AGENT_0']
#     AGENT_0:
#       ANGULAR_ACCELERATION: 12.56
#       ANGULAR_FRICTION: 1.0
#       COEFFICIENT_OF_RESTITUTION: 0.0
#       HEIGHT: 1.5
#       IS_SET_START_STATE: False
#       LINEAR_ACCELERATION: 20.0
#       LINEAR_FRICTION: 0.5
#       MASS: 32.0
#       RADIUS: 0.1
#       SENSORS: ['DEPTH_SENSOR']
#       START_POSITION: [0, 0, 0]
#       START_ROTATION: [0, 0, 0, 1]
#     DEFAULT_AGENT_ID: 0
#     DEPTH_SENSOR:
#       HEIGHT: 256
#       HFOV: 90
#       MAX_DEPTH: 10.0
#       MIN_DEPTH: 0.0
#       NORMALIZE_DEPTH: True
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimDepthSensor
#       WIDTH: 256
#     FORWARD_STEP_SIZE: 0.25
#     HABITAT_SIM_V0:
#       ALLOW_SLIDING: True
#       ENABLE_PHYSICS: False
#       GPU_DEVICE_ID: 0
#       GPU_GPU: False
#       PHYSICS_CONFIG_FILE: ./data/default.phys_scene_config.json
#     RGB_SENSOR:
#       HEIGHT: 256
#       HFOV: 90
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimRGBSensor
#       WIDTH: 256
#     SCENE: data/scene_datasets/habitat-test-scenes/van-gogh-room.glb
#     SEED: 100
#     SEMANTIC_SENSOR:
#       HEIGHT: 480
#       HFOV: 90
#       POSITION: [0, 1.25, 0]
#       TYPE: HabitatSimSemanticSensor
#       WIDTH: 640
#     TILT_ANGLE: 15
#     TURN_ANGLE: 10
#     TYPE: Sim-v0
#   TASK:
#     ACTIONS:
#       ANSWER:
#         TYPE: AnswerAction
#       LOOK_DOWN:
#         TYPE: LookDownAction
#       LOOK_UP:
#         TYPE: LookUpAction
#       MOVE_FORWARD:
#         TYPE: MoveForwardAction
#       STOP:
#         TYPE: StopAction
#       TELEPORT:
#         TYPE: TeleportAction
#       TURN_LEFT:
#         TYPE: TurnLeftAction
#       TURN_RIGHT:
#         TYPE: TurnRightAction
#     ANSWER_ACCURACY:
#       TYPE: AnswerAccuracy
#     COLLISIONS:
#       TYPE: Collisions
#     COMPASS_SENSOR:
#       TYPE: CompassSensor
#     CORRECT_ANSWER:
#       TYPE: CorrectAnswer
#     DISTANCE_TO_GOAL:
#       DISTANCE_TO: POINT
#       TYPE: DistanceToGoal
#     EPISODE_INFO:
#       TYPE: EpisodeInfo
#     GOAL_SENSOR_UUID: pointgoal_with_gps_compass
#     GPS_SENSOR:
#       DIMENSIONALITY: 2
#       TYPE: GPSSensor
#     HEADING_SENSOR:
#       TYPE: HeadingSensor
#     INSTRUCTION_SENSOR:
#       TYPE: InstructionSensor
#     INSTRUCTION_SENSOR_UUID: instruction
#     MEASUREMENTS: ['DISTANCE_TO_GOAL', 'SPL']
#     OBJECTGOAL_SENSOR:
#       GOAL_SPEC: TASK_CATEGORY_ID
#       GOAL_SPEC_MAX_VAL: 50
#       TYPE: ObjectGoalSensor
#     POINTGOAL_SENSOR:
#       DIMENSIONALITY: 2
#       GOAL_FORMAT: POLAR
#       TYPE: PointGoalSensor
#     POINTGOAL_WITH_GPS_COMPASS_SENSOR:
#       DIMENSIONALITY: 2
#       GOAL_FORMAT: POLAR
#       TYPE: PointGoalWithGPSCompassSensor
#     POSSIBLE_ACTIONS: ['STOP', 'MOVE_FORWARD', 'TURN_LEFT', 'TURN_RIGHT']
#     PROXIMITY_SENSOR:
#       MAX_DETECTION_RADIUS: 2.0
#       TYPE: ProximitySensor
#     QUESTION_SENSOR:
#       TYPE: QuestionSensor
#     SENSORS: ['POINTGOAL_WITH_GPS_COMPASS_SENSOR']
#     SPL:
#       SUCCESS_DISTANCE: 0.2
#       TYPE: SPL
#     SUCCESS_DISTANCE: 0.2
#     TOP_DOWN_MAP:
#       DRAW_BORDER: True
#       DRAW_GOAL_AABBS: True
#       DRAW_GOAL_POSITIONS: True
#       DRAW_SHORTEST_PATH: True
#       DRAW_SOURCE: True
#       DRAW_VIEW_POINTS: True
#       FOG_OF_WAR:
#         DRAW: True
#         FOV: 90
#         VISIBILITY_DIST: 5.0
#       MAP_PADDING: 3
#       MAP_RESOLUTION: 1250
#       MAX_EPISODE_STEPS: 1000
#       NUM_TOPDOWN_MAP_SAMPLE_POINTS: 20000
#       TYPE: TopDownMap
#     TYPE: Nav-v0
# TENSORBOARD_DIR: tb
# TEST_EPISODE_COUNT: 994
# TORCH_GPU_ID: 0
# TRAINER_NAME: ddppo
# VIDEO_DIR: video_dir
# VIDEO_OPTION: []
# 2020-02-27 05:42:42,311 Initializing dataset PointNav-v1
# 2020-02-27 05:42:43,518 Initializing dataset PointNav-v1
# 2020-02-27 05:42:43,518 Initializing dataset PointNav-v1
# 2020-02-27 05:42:43,518 Initializing dataset PointNav-v1
# 2020-02-27 05:42:43,531 initializing sim Sim-v0
# 2020-02-27 05:42:43,531 initializing sim Sim-v0
# 2020-02-27 05:42:43,531 initializing sim Sim-v0
# 2020-02-27 05:42:43,533 Initializing dataset PointNav-v1
# 2020-02-27 05:42:43,546 initializing sim Sim-v0
# 2020-02-27 05:42:45,147 Initializing task Nav-v0
# 2020-02-27 05:42:48,016 Initializing task Nav-v0
# 2020-02-27 05:42:48,379 Initializing task Nav-v0
# 2020-02-27 05:42:48,442 Initializing task Nav-v0
# 2020-02-27 05:51:57,406 Average episode reward: 5.167987
# 2020-02-27 05:51:57,412 Average episode success: 1.000000
# 2020-02-27 05:51:57,416 Average episode distance_to_goal: 1.012711
